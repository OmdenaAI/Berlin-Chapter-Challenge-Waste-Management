# %%
import json
import pandas as pd

# %%
with open('E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\1-raw data\\Geospatial Data\\landfills\\Landfill_Hamburg(DE-HH).json', 
          'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

# %%
new_data_list = []

for entry in data["elements"]:
    new_entry = {
        **entry.get("tags", {}),  
        "type": entry.get("type", None),  
        "id": entry.get("id", None), 
        "lat": entry.get("lat", None),  
        "lon": entry.get("lon", None), 
    }
    new_data_list.append(new_entry)

# %%
df = pd.DataFrame(new_data_list)

# %%
df.shape
# Out:
# (213, 74)

# %%
df.head()
# Out:
#     landuse type         id  lat  lon barrier                      name
# 0  landfill  way   54173496  NaN  NaN     NaN                       NaN  \
# 1  landfill  way   62140227  NaN  NaN   fence                       NaN
# 2  landfill  way  101396796  NaN  NaN     NaN     Spülfeld Moorburg-Ost
# 3  landfill  way  101396818  NaN  NaN     NaN   Spülfeld Moorburg-Mitte
# 4  landfill  way  101712461  NaN  NaN     NaN  Schlick-Deponie Feldhofe
#
#   informal landfill:waste ISO3166-2  ... ref:nuts:3 short_name source
# 0      NaN            NaN       NaN  ...        NaN        NaN    NaN  \
# 1      NaN            NaN       NaN  ...        NaN        NaN    NaN
# 2      NaN            NaN       NaN  ...        NaN        NaN    NaN
# 3      NaN            NaN       NaN  ...        NaN        NaN    NaN
# 4      NaN            NaN       NaN  ...        NaN        NaN    NaN
#
#   wikidata wikipedia de:name_index_city de:place description land_area
# 0      NaN       NaN                NaN      NaN         NaN       NaN  \
# 1      NaN       NaN                NaN      NaN         NaN       NaN
# 2      NaN       NaN                NaN      NaN         NaN       NaN
# 3      NaN       NaN                NaN      NaN         NaN       NaN
# 4      NaN       NaN                NaN      NaN         NaN       NaN
#
#   name:prefix:de
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 74 columns]

# %%
df.isnull().sum()
# Out:
# landuse               204
# type                    0
# id                      0
# lat                    11
# lon                    11
#                      ...
# de:name_index_city    212
# de:place              212
# description           212
# land_area             212
# name:prefix:de        212
# Length: 74, dtype: int64

# %%
df.dropna(subset=['lat', 'lon'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\work.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/mygit/Berlin-Chapter-Challenge-Waste-Management/src/data/3-clean%20data/Data_Rework/Geospatial%20Data/Landfills/work.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df.dropna(subset=['lat', 'lon'], inplace=True)
#
# NameError: name 'df' is not defined

# %%
columns_to_delete = ['ISO3166-2','opening_hours:summer','nohousenumber','bicycle','roof:height', 'leaf_type', 
    'postal_code','location', 'check_date:recycling', 'highway', 'surface', 'covered', 'indoor', 'building',
    'fixme', 'contact:email', 'contact:phone', 'contact:website', 'operator:short', 'addr:suburb',
    'is_in', 'colour', 'brand', 'brand:wikidata', 'ref', 'fax', 'ele', 'internet', 'source:operator',
    'name:de', 'source:ref', 'opening_hours:problematic_waste', 'name:signed', 'opening_hours:url',
    'underground', 'source:amenity', 'description:de','opening_hours:signed', 'note:position','man_made',
    'park_ride','operator:mobile','fence_type','roof:shape','source:outline',
    'toilets:wheelchair','charge','manufacturer','source:opening_hours','payment:credit_cards','official_name:de','long_name',
    'payment:debit_cards','payment:maestro','payment:notes',
    'generator:method','generator:output:electricity','generator:source','height','area','fence','roof:colour','operator:fax',
    'opening_hours:text','object:city','object:postcode','object:street','building:colour','building:material','roof:material',
    'roof:levels','payment:cash','description:en','leaf_type''roof:height','building_1','building:levels','parking',
    'fenced','owner','leisure','note:de', 'alt_name','source:position', 'short_name',
    'power', 'surveillance', 'glasstype', 'operator:email','operator:phone', 'start_date', 'wheelchair:description',
    'source:date','wikipedia','level','contact:fax','video','contact:mobile',
    'barrier','landuse','name:es','name:fr','layer','lit','inscription',
    'oper', 'operator:signed', 'operator:website',
    'check_date:surface','not:brand:wikidata','noname', 'opening_hours:winter','amenity','check_date','addr:city',
    'addr:country','addr:housenumber',
    'addr:postcode','FIXME','check_date:opening_hours','operator','source','description','operator:wikidata',
    'operator:wikipedia','direction','wheelchair','addr:street','website','addr:place',
    'addr:housename','shop','url',
    'brand:wikipedia',
    'checked',
    'damage:event', 'demolished:tourism', 'old_name', 'recycling:batteries',
    'recycling:cans', 'recycling:cardboard', 'recycling:clothes', 'recycling:electrical_appliances',
    'recycling:glass_bottles', 'recycling:green_waste', 'recycling:paper', 'recycling:plastic',
    'recycling:plastic_bottles', 'recycling:plastic_packaging', 'recycling:scrap_metal', 'recycling:shoes',
    'recycling:small_appliances', 'recycling:waste', 'recycling:white_goods', 'recycling:glass',
    'recycling:wood', 'recycling:construction_waste', 'disused:landuse', 'disused', 'storage',
    'visibility', 'service', 'informal', 'natural', 'recycling:garden_waste', 'landfill:waste', 'waste',
    'foot', 'motorcar', 'motorcycle', 'motor_vehicle', 'recycling:electrical_appliances',
    'recycling:small_electrical_appliances', 'generator:type', 'landfill:waste', 'old_name', 'natural',
    'disused', 'alt_name:pt', 'name:nds', 'name:zh-Hans', 'name:zh-Hant', 'foot', 'motorcar', 'motorcycle',
    'depth', 'headframe', 'mineshaft:wikidata', 'mineshaft_type', 'disused', 'landfill:waste', 'recycling:soil',
    'old_name', 'product', 'natural', 'historic', 'collection_times', 'recycling:batteries',
    'recycling:electrical_appliances', 'recycling:green_waste', 'recycling:paper', 'recycling:plastic_packaging',
    'recycling:scrap_metal', 'recycling:small_appliances', 'recycling:waste', 'contaminated', 'step_count',
    'recycling:cans', 'recycling:clothes', 'recycling:clothes', 'recycling:glass', 'recycling:garden_waste',
    'recycling:wood', 'payment:coins', 'payment:cryptocurrencies', 'payment:electronic_purses',
    'recycling:hardcore', 'name:pfl', 'name:tzl', 'foot', 'seats', 'maxspeed', 'traffic_sign', 'motorcar',
    'motorcycle', 'locked',
    'material',
    'loc_ref',
    'name:en',
    'email',
    'note:operator',
    'last_check',
    'note:opening_hours',
    'opening_hours:covid19',
    'image','recycling:de',
    'brand:short',
    'wikimedia_commons',
    'access',
    'mapillary','last_checked',
    'operator:type',
    'note',
    'survey:date',
    'name','created_by',
    'opening_hours',
    'phone',
    'recycling_type',
    'type',     'resource',
'coat_of_arms',
'flag',
'nickname',
'nickname:ar',
'nickname:cs',
'nickname:de',
'nickname:en',
'nickname:eo',
'nickname:fr',
'nickname:fy',
'nickname:hsb',
'nickname:hu',
'nickname:la',
'nickname:nds','nickname:fy',
'nickname:hsb',
'nickname:hu',
'nickname:la',
'nickname:nds',
'nickname:pl',
'nickname:ru',
'official_name:eo',
'official_name:fr',
'official_name:fy',
'official_name:hsb',
'official_name:hu',
'official_name:la',
'official_name:nds',
'official_name:pl',
'official_name:ru',
'ref:nuts:2','direction_west',
'support',
    'contact:city',
    'contact:housenumber',
    'contact:postcode',
    'contact:street',
    'admin_level',
    'alt_name:eo',
    'border_type','designation',
    'hiking',
    'information',
    'map_size',
    'map_type',
    'mtb',
    'tourism',
    'boundary',
    'TMC:cid_58:tabcd_1:Class',
    'TMC:cid_58:tabcd_1:LCLversion',
    'TMC:cid_58:tabcd_1:LocationCode','de:amtlicher_gemeindeschluessel',
    'de:regionalschluessel',
    'int_name',
    'name:af',
    'name:am',
    'name:an',
    'name:ar',
    'name:ay',
    'name:az',
    'name:ba',
    'name:be',
    'name:bg',
    'name:bn',
    'name:br',
    'name:bs',
    'name:ca',
    'name:ce',
    'name:cs',
    'name:cv',
    'name:cy',
    'name:el',
    'name:eo',
    'name:et',
    'name:eu',
    'name:fa',
    'name:fi',
    'name:fy',
    'name:ga',
    'name:gd',
    'name:gl',
    'name:gn',
    'name:gv',
    'name:he',
    'name:hi',
    'name:hr',
    'name:hsb',
    'name:hu',
    'name:hy',
    'name:ia',
    'name:ie',
    'name:io',
    'name:is',
    'name:it',
    'name:ja',
    'name:ka',
    'name:kg',
    'name:kk',
    'name:ko',
    'name:ky',
    'name:la',
    'name:li',
    'name:lt',
    'name:lv',
    'name:mk',
    'name:ml',
    'name:mn',
    'name:mr',
    'name:ms',
    'name:mt',
    'name:nl',
    'name:oc',
    'name:os',
    'name:pa',
    'name:pl',
    'name:prefix',
    'name:pt',
    'name:rm',
    'name:ro',
    'name:ru',
    'name:sc',
    'name:sk',
    'name:sl',
    'name:sq',
    'name:sr',
    'name:sw',
    'name:szl',
    'name:ta',
    'name:te',
    'name:th',
    'name:tk',
    'name:tl',
    'logo', 'nickname:pt', 'official_name:pt', 'official_status',
    'official_status:ar', 'official_status:de', 'official_status:en', 'official_status:ru',
    'ref:LOCODE', 'ref:nuts:3', 'de:name_index_city', 'de:place', 'name:prefix:de', 'content',
    'addr:inclusion', 'recycling:building', 'alt_name:vi', 'contact:facebook', 'de:place',
    'geographical_region', 'license_plate_code', 'name:als', 'name:ang', 'name:arc', 'name:ast',
    'name:bar', 'name:bat-smg', 'name:be-tarask', 'name:bi', 'name:bo', 'name:cbk-zam', 'name:crh',
    'name:csb', 'name:cu', 'name:da', 'name:diq', 'name:dsb', 'name:fo', 'name:frp', 'name:fur',
    'name:haw', 'name:ht', 'name:id', 'name:ilo', 'name:jbo', 'name:jv', 'name:kab', 'name:ksh',
    'name:ku', 'name:kv', 'name:kw', 'name:lb', 'name:lg', 'name:lij', 'name:lmo', 'name:ln',
    'name:lzh', 'name:mg', 'name:myv', 'name:na', 'name:nah', 'name:nan', 'name:nap', 'name:nn',
    'name:no', 'name:nov', 'name:nrm', 'name:pam', 'name:pdc', 'name:pms', 'name:prefix:city',
    'name:prefix:state', 'name:qu', 'name:rmy', 'name:roa-rup', 'name:roa-tara', 'name:sah',
    'name:scn', 'name:sco', 'name:se', 'name:sh', 'name:short', 'name:so', 'name:stq', 'name:su',
    'name:sv', 'name:tet', 'name:tg', 'name:tpi', 'name:ty', 'name:vec', 'name:vi', 'name:vls',
    'name:wo', 'name:yue', 'name:zu', 'official_status', 'official_status:de', 'official_status:en',
    'official_status:ru', 'old_name:vi', 'place', 'population', 'ref:nuts:3', 'report_problems:website',
    'source:population', 'state_code',
    'recycling:others', 'recycling:rubble', 'lastcheck', 'loc_name', 'recycling:aluminium',
    'recycling:cds', 'recycling:earth', 'recycling:electrical_items', 'recycling:electronic',
    'recycling:electronic_scrap', 'recycling:electronics', 'recycling:tires', 'disused:amenity',
    'disused:opening_hours', 'disused:recycling:hardcore', 'disused:recycling:others',
    'disused:recycling:rubble', 'disused:recycling_type', 'recycling:hardcode', 'source:addr',
    'abandoned', 'source:geometry', 'recycling:organic', 'BBP', 'old_operator', 'crop',
    'old_short_name', 'old_highway', 'capacity', 'abandoned:landuse', 'alt_name:cs', 'name:gsw',
    'name:ps', 'vehicle', 'emergency', 'gate:type', 'entrance', 'goods', 'hgv', 'horse',
    'name:tr',
    'name:tt',
    'name:uk',
    'name:ur',
    'name:uz',
    'name:vo',
    'name:yi',
    'name:yo',
    'name:zh','land_area',
    'official_name',
    'official_name:ar',
    'official_name:cs',
    'official_name:en',
    'official_name:sk',
    'official_name:sr',
    'old_name:cs','military',
'landfill:class',
'comment','landfill',
'waterway',
'alt_name:ca',
    'ref:nuts',
    'ref:nuts:1',
    'wikidata',]

# %%
df.to_csv('Landfills_Hamburg(DE-HH).csv', index=False)

# %%
def delete_columns(df, columns_to_delete):
    for column in columns_to_delete:
        if column in df.columns:
            df.drop(column, axis=1, inplace=True)
    return df

# %%
paths = { 
        #"E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Bremen.csv" : "Bremen", 
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Brandenburg.csv" : "Brandenburg",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Berlin.csv" : "Berlin",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Bavaria.csv" : "Bavaria",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Baden_Wurttemberg.csv" : "Baden_Württemberg",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills__Saxony(DE-SN).csv" : "Saxony",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills__Saarland(DE-SL).csv" : "Saarland",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_North Rhine-Westphalia (DE-NW).csv" : "North Rhine-Westphalia",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Hamburg(DE-HH).csv" : "Hamburg",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Hesse(DE-HE).csv" : "Hesse",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Lower Saxony (DE-NI).csv" : "Lower Saxony",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Mecklenburg-Vorpommern(DE-MV).csv" : "Mecklenburg-Vorpommern",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Rhineland-Palatinate (DE-RP).csv" : "Rhineland-Palatinate",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Hamburg(DE-HH).csv" : "Hamburg",
        "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Thuringia.csv" : "Thuringia"
}

# %%
def add_state(paths):
    for file_path, state_name in paths.items():  
        try:
            df = pd.read_csv(file_path)
            df['state'] = state_name
            df['station'] = "landfills"
            df = delete_columns(df, columns_to_delete) 

            column_list = df.columns
            print("........")
            for column in column_list:
                
                print(f"'{column}',")
            
            df.to_csv(file_path, index=False)
            
            print(f"Added 'state' column to {file_path} with state name: {state_name}")
        except Exception as e:
            print(f"Error processing {file_path}: {str(e)}")

add_state(paths)
# Out:
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_Bremen.csv with state name: Bremen
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_Brandenburg.csv with state name: Brandenburg
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_Berlin.csv with state name: Berlin
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_Bavaria.csv with state name: Bavaria
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_Baden_Württemberg.csv with state name: Baden_Württemberg
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills__Saxony(DE-SN).csv with state name: Saxony
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills__Saarland(DE-SL).csv with state name: Saarland
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_North Rhine-Westphalia (DE-NW).csv with state name: North Rhine-Westphalia
# Error processing E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_Landfills_Hamburg(DE-HH).csv: [Errno 2] No such file or directory: 'E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\Landfills_Landfills_Hamburg(DE-HH).csv'
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_Hesse(DE-HE).csv with state name: Hesse
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_Lower Saxony (DE-NI).csv with state name: Lower Saxony
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_Mecklenburg-Vorpommern(DE-MV).csv with state name: Mecklenburg-Vorpommern
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_Rhineland-Palatinate (DE-RP).csv with state name: Rhineland-Palatinate
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_Hamburg(DE-HH).csv with state name: Hamburg
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Landfills\Landfills_Thuringia.csv with state name: Thuringia

# %%
def concatenate_csv_files(csv_paths, output_file):
    complete_df = pd.DataFrame()
    
    for csv_path, _ in csv_paths.items(): 
        df = pd.read_csv(csv_path)
        complete_df = pd.concat([complete_df, df], ignore_index=True)
        
    complete_df.to_csv(output_file, index=False)

# %%
output_file = 'complete_landfills.csv'  
concatenate_csv_files(paths, output_file)

# %%
df1 = pd.read_csv("E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Landfills\\complete_landfills.csv")

# %%
df1.sample(10)
# Out:
#                 id        lat        lon                 state    station
# 21144    153292043  50.626996   8.471253          Lower Saxony  landfills
# 6135     747679933  48.299949   9.260516     Baden_Württemberg  landfills
# 16695     27039924  49.614203   8.471657                 Hesse  landfills
# 26682   2440497763  50.840700   7.971299  Rhineland-Palatinate  landfills
# 7084     255730600  48.675855   9.503423     Baden_Württemberg  landfills
# 21211   1228449278  50.609667   8.837584          Lower Saxony  landfills
# 19022   1406974038  51.090053   9.316606                 Hesse  landfills
# 11651   2158121927  50.801605  12.616467                Saxony  landfills
# 25073   1719820558  49.757354   8.201667  Rhineland-Palatinate  landfills
# 10008  10775986210  50.724217  12.560668                Saxony  landfills
