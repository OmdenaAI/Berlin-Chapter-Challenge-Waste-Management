# %%
import json
import pandas as pd
import numpy as np

# %%
with open('E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\1-raw data\\Geospatial Data\\waste transfer centres\\WasteTransferSite_SaxonyAnhalt.json'
          ,'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

# %%
new_data_list = []

for entry in data["elements"]:
    new_entry = {
        **entry.get("tags", {}),  # Use a default empty dictionary if "tags" doesn't exist
        "type": entry.get("type", None),  # Use None if "type" doesn't exist
        "id": entry.get("id", None),  # Use None if "id" doesn't exist
        "lat": entry.get("lat", None),  # Use None if "lat" doesn't exist
        "lon": entry.get("lon", None),  # Use None if "lon" doesn't exist
    }
    new_data_list.append(new_entry)

# %%
original_df = pd.DataFrame(new_data_list)

# %%
column_list = original_df.columns
print(column_list)
# Out:
# Index(['amenity', 'type', 'id', 'lat', 'lon', 'addr:city', 'addr:housenumber',
#        'addr:postcode', 'addr:street', 'name', 'opening_hours', 'phone',
#        'waste', 'website', 'barrier', 'landuse', 'operator', 'ISO3166-2',
#        'TMC:cid_58:tabcd_1:Class', 'TMC:cid_58:tabcd_1:LCLversion',
#        'TMC:cid_58:tabcd_1:LocationCode', 'admin_level', 'alt_name:eo',
#        'alt_name:pt', 'border_type', 'boundary',
#        'de:amtlicher_gemeindeschluessel', 'de:regionalschluessel', 'name:ar',
#        'name:ca', 'name:cs', 'name:de', 'name:en', 'name:eo', 'name:es',
#        'name:fa', 'name:fr', 'name:hr', 'name:hsb', 'name:hu', 'name:ia',
#        'name:io', 'name:is', 'name:it', 'name:lt', 'name:mk', 'name:nl',
#        'name:pl', 'name:prefix', 'name:pt', 'name:ru', 'name:sk', 'name:sl',
#        'name:sr', 'name:sv', 'name:th', 'name:uk', 'name:ur', 'name:vo',
#        'name:zh', 'name:zh-Hans', 'name:zh-Hant', 'ref', 'ref:nuts:1',
# ...

# %%
original_df.head()
# Out:
#                   amenity  type           id        lat        lon
# 0  waste_transfer_station   way    724666576        NaN        NaN  \
# 1  waste_transfer_station   way    839558358        NaN        NaN
# 2  waste_transfer_station   way    981177092        NaN        NaN
# 3                     NaN  area   3600062607        NaN        NaN
# 4                     NaN  node  10749073433  51.548581  12.049462
#
#          addr:city addr:housenumber addr:postcode       addr:street
# 0              NaN              NaN           NaN               NaN  \
# 1  Köthen (Anhalt)               60         06366  Maxdorfer Straße
# 2              NaN              NaN           NaN               NaN
# 3              NaN              NaN           NaN               NaN
# 4              NaN              NaN           NaN               NaN
#
#                                              name  ...          name:vo
# 0                                             NaN  ...              NaN  \
# ...

# %%
df = original_df[['id', 'lat', 'lon']].copy()

# %%
df.shape
# Out:
# (50, 3)

# %%
df.head()
# Out:
#             id        lat        lon
# 0    724666576        NaN        NaN
# 1    839558358        NaN        NaN
# 2    981177092        NaN        NaN
# 3   3600062607        NaN        NaN
# 4  10749073433  51.548581  12.049462

# %%
df.to_csv('WasteTransferStations_SaxonyAnhalt.csv', index=False)

# %% [markdown]
# # Work 2.0

# %%
import numpy as np
import pandas as pd

# %%
columns_to_delete = ['ISO3166-2','opening_hours:summer','nohousenumber','bicycle','roof:height', 'leaf_type', 
    'postal_code','location', 'check_date:recycling', 'highway', 'surface', 'covered', 'indoor', 'building',
    'fixme', 'contact:email', 'contact:phone', 'contact:website', 'operator:short', 'addr:suburb',
    'is_in', 'colour', 'brand', 'brand:wikidata', 'ref', 'fax', 'ele', 'internet', 'source:operator',
    'name:de', 'source:ref', 'opening_hours:problematic_waste', 'name:signed', 'opening_hours:url',
    'underground', 'source:amenity', 'description:de','opening_hours:signed', 'note:position','man_made',
    'park_ride','operator:mobile','fence_type','roof:shape','source:outline',
    'toilets:wheelchair','charge','manufacturer','source:opening_hours','payment:credit_cards','official_name:de','long_name',
    'payment:debit_cards','payment:maestro','payment:notes',
    'generator:method','generator:output:electricity','generator:source','height','area','fence','roof:colour','operator:fax',
    'opening_hours:text','object:city','object:postcode','object:street','building:colour','building:material','roof:material',
    'roof:levels','payment:cash','description:en','leaf_type''roof:height','building_1','building:levels','parking',
    'fenced','owner','leisure','note:de', 'alt_name','source:position', 'short_name',
    'power', 'surveillance', 'glasstype', 'operator:email','operator:phone', 'start_date', 'wheelchair:description',
    'source:date','wikipedia','level','contact:fax','video','contact:mobile',
    'barrier','landuse','name:es','name:fr','layer','lit','inscription',
    'oper', 'operator:signed', 'operator:website',
    'check_date:surface','not:brand:wikidata','noname', 'opening_hours:winter','amenity','check_date','addr:city',
    'addr:country','addr:housenumber',
    'addr:postcode','FIXME','check_date:opening_hours','operator','source','description','operator:wikidata',
    'operator:wikipedia','direction','wheelchair','addr:street','website','addr:place',
    'addr:housename','shop','url',
    'brand:wikipedia',
    'checked',
    'damage:event', 'demolished:tourism', 'old_name', 'recycling:batteries',
    'recycling:cans', 'recycling:cardboard', 'recycling:clothes', 'recycling:electrical_appliances',
    'recycling:glass_bottles', 'recycling:green_waste', 'recycling:paper', 'recycling:plastic',
    'recycling:plastic_bottles', 'recycling:plastic_packaging', 'recycling:scrap_metal', 'recycling:shoes',
    'recycling:small_appliances', 'recycling:waste', 'recycling:white_goods', 'recycling:glass',
    'recycling:wood', 'recycling:construction_waste', 'disused:landuse', 'disused', 'storage',
    'visibility', 'service', 'informal', 'natural', 'recycling:garden_waste', 'landfill:waste', 'waste',
    'foot', 'motorcar', 'motorcycle', 'motor_vehicle', 'recycling:electrical_appliances',
    'recycling:small_electrical_appliances', 'generator:type', 'landfill:waste', 'old_name', 'natural',
    'disused', 'alt_name:pt', 'name:nds', 'name:zh-Hans', 'name:zh-Hant', 'foot', 'motorcar', 'motorcycle',
    'depth', 'headframe', 'mineshaft:wikidata', 'mineshaft_type', 'disused', 'landfill:waste', 'recycling:soil',
    'old_name', 'product', 'natural', 'historic', 'collection_times', 'recycling:batteries',
    'recycling:electrical_appliances', 'recycling:green_waste', 'recycling:paper', 'recycling:plastic_packaging',
    'recycling:scrap_metal', 'recycling:small_appliances', 'recycling:waste', 'contaminated', 'step_count',
    'recycling:cans', 'recycling:clothes', 'recycling:clothes', 'recycling:glass', 'recycling:garden_waste',
    'recycling:wood', 'payment:coins', 'payment:cryptocurrencies', 'payment:electronic_purses',
    'recycling:hardcore', 'name:pfl', 'name:tzl', 'foot', 'seats', 'maxspeed', 'traffic_sign', 'motorcar',
    'motorcycle', 'locked','material','loc_ref','name:en','email','note:operator','last_check','note:opening_hours',
    'opening_hours:covid19','image','recycling:de','brand:short','wikimedia_commons','access','mapillary','last_checked',
    'operator:type','note','survey:date','name','created_by','opening_hours','phone','recycling_type',
    'type','resource','coat_of_arms','flag','nickname','nickname:ar','nickname:cs','nickname:de','nickname:en','nickname:eo','nickname:fr',
'nickname:fy','nickname:hsb','nickname:hu','nickname:la','nickname:nds','nickname:fy','nickname:hsb','nickname:hu','nickname:la','nickname:nds','nickname:pl',
'nickname:ru','official_name:eo','official_name:fr','official_name:fy',
'official_name:hsb','official_name:hu','official_name:la','official_name:nds','official_name:pl','official_name:ru','ref:nuts:2','direction_west',
'support',
    'contact:city',
    'contact:housenumber',
    'contact:postcode',
    'contact:street',
    'admin_level',
    'alt_name:eo',
    'border_type','designation',
    'hiking',
    'information',
    'map_size',
    'map_type',
    'mtb',
    'tourism',
    'boundary',
    'TMC:cid_58:tabcd_1:Class',
    'TMC:cid_58:tabcd_1:LCLversion',
    'TMC:cid_58:tabcd_1:LocationCode','de:amtlicher_gemeindeschluessel',
    'de:regionalschluessel',
    'int_name',
    'name:af',
    'name:am',
    'name:an',
    'name:ar',
    'name:ay',
    'name:az',
    'name:ba',
    'name:be',
    'name:bg',
    'name:bn',
    'name:br',
    'name:bs',
    'name:ca',
    'name:ce',
    'name:cs',
    'name:cv',
    'name:cy',
    'name:el',
    'name:eo',
    'name:et',
    'name:eu',
    'name:fa',
    'name:fi',
    'name:fy',
    'name:ga',
    'name:gd',
    'name:gl',
    'name:gn',
    'name:gv',
    'name:he',
    'name:hi',
    'name:hr',
    'name:hsb',
    'name:hu',
    'name:hy',
    'name:ia',
    'name:ie',
    'name:io',
    'name:is',
    'name:it',
    'name:ja',
    'name:ka',
    'name:kg',
    'name:kk',
    'name:ko',
    'name:ky',
    'name:la',
    'name:li',
    'name:lt',
    'name:lv',
    'name:mk',
    'name:ml',
    'name:mn',
    'name:mr',
    'name:ms',
    'name:mt',
    'name:nl',
    'name:oc',
    'name:os',
    'name:pa',
    'name:pl',
    'name:prefix',
    'name:pt',
    'name:rm',
    'name:ro',
    'name:ru',
    'name:sc',
    'name:sk',
    'name:sl',
    'name:sq',
    'name:sr',
    'name:sw',
    'name:szl',
    'name:ta',
    'name:te',
    'name:th',
    'name:tk',
    'name:tl',
    'logo', 'nickname:pt', 'official_name:pt', 'official_status',
    'official_status:ar', 'official_status:de', 'official_status:en', 'official_status:ru',
    'ref:LOCODE', 'ref:nuts:3', 'de:name_index_city', 'de:place', 'name:prefix:de', 'content',
    'addr:inclusion', 'recycling:building', 'alt_name:vi', 'contact:facebook', 'de:place',
    'geographical_region', 'license_plate_code', 'name:als', 'name:ang', 'name:arc', 'name:ast',
    'name:bar', 'name:bat-smg', 'name:be-tarask', 'name:bi', 'name:bo', 'name:cbk-zam', 'name:crh',
    'name:csb', 'name:cu', 'name:da', 'name:diq', 'name:dsb', 'name:fo', 'name:frp', 'name:fur',
    'name:haw', 'name:ht', 'name:id', 'name:ilo', 'name:jbo', 'name:jv', 'name:kab', 'name:ksh',
    'name:ku', 'name:kv', 'name:kw', 'name:lb', 'name:lg', 'name:lij', 'name:lmo', 'name:ln',
    'name:lzh', 'name:mg', 'name:myv', 'name:na', 'name:nah', 'name:nan', 'name:nap', 'name:nn',
    'name:no', 'name:nov', 'name:nrm', 'name:pam', 'name:pdc', 'name:pms', 'name:prefix:city',
    'name:prefix:state', 'name:qu', 'name:rmy', 'name:roa-rup', 'name:roa-tara', 'name:sah',
    'name:scn', 'name:sco', 'name:se', 'name:sh', 'name:short', 'name:so', 'name:stq', 'name:su',
    'name:sv', 'name:tet', 'name:tg', 'name:tpi', 'name:ty', 'name:vec', 'name:vi', 'name:vls',
    'name:wo', 'name:yue', 'name:zu', 'official_status', 'official_status:de', 'official_status:en',
    'official_status:ru', 'old_name:vi', 'place', 'population', 'ref:nuts:3', 'report_problems:website',
    'source:population', 'state_code',
    'recycling:others', 'recycling:rubble', 'lastcheck', 'loc_name', 'recycling:aluminium',
    'recycling:cds', 'recycling:earth', 'recycling:electrical_items', 'recycling:electronic',
    'recycling:electronic_scrap', 'recycling:electronics', 'recycling:tires', 'disused:amenity',
    'disused:opening_hours', 'disused:recycling:hardcore', 'disused:recycling:others',
    'disused:recycling:rubble', 'disused:recycling_type', 'recycling:hardcode', 'source:addr',
    'abandoned', 'source:geometry', 'recycling:organic', 'BBP', 'old_operator', 'crop',
    'old_short_name', 'old_highway', 'capacity', 'abandoned:landuse', 'alt_name:cs', 'name:gsw',
    'name:ps', 'vehicle', 'emergency', 'gate:type', 'entrance', 'goods', 'hgv', 'horse','name:tr',
    'name:tt',
    'name:uk',
    'name:ur',
    'name:uz',
    'name:vo',
    'name:yi',
    'name:yo',
    'name:zh','land_area',
    'official_name',
    'official_name:ar',
    'official_name:cs',
    'official_name:en',
    'official_name:sk',
    'official_name:sr',
'old_name:cs','military',
'landfill:class',
'comment','landfill',
'waterway',
'alt_name:ca',
    'ref:nuts',
    'ref:nuts:1',
    'wikidata',]

# %%
def delete_columns(df, columns_to_delete):
    for column in columns_to_delete:
        if column in df.columns:
            df.drop(column, axis=1, inplace=True)
    return df

# %%
paths = {
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_Baden-Wurttemberg.csv" : "Baden-Wurttemberg", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_Bavaria.csv" : "Bavaria", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_Berlin.csv" : "Berlin", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_Brandenburg.csv" : "Bradenburg", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_Bremen.csv" : "Bremen", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_Hamburg_DE-HH.csv" : "Hamburg", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_Hesse_DE-HE.csv" : "Hesse", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_Lower_Saxony_Niedersachsen_DE-NI.csv" : "LowerSaxony_Niedersachsen", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStationsRhineland-Palatinate_DE-RP.csv" : "Rhineland-Palatinate", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_Mecklenburg_Vorpommen_DE-MV.csv" : "Mecklenburg_Vorpommern", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_Saarland_DE_SL.csv" : "Saarland", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_SaxonyAnhalt.csv" : "Saxony-Anhalt", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_SchleswigHolstein.csv" : "Schleswig-Holstein", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_Thuringia.csv" : "Thuringia", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_North_Rhine-Westphalia_DE-NW.csv" : "NorthRhine-Westphalia", 
   "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Transfer Stations\\WasteTransferStations_Saxony_DE-SN.csv" : "Saxony",
    }

# %%
def add_state(paths):
    for file_path, state_name in paths.items():  
        try:
            df = pd.read_csv(file_path)
            df['state'] = state_name
            df['station'] = "waste transfer stations"
            df = delete_columns(df, columns_to_delete) 

            column_list = df.columns
            print("........")
            for column in column_list:
                
                print(f"'{column}',")
            
            df.to_csv(file_path, index=False)
            
            print(f"Added 'state' column to {file_path} with state name: {state_name}")
        except Exception as e:
            print(f"Error processing {file_path}: {str(e)}")

# %%
add_state(paths)
# Out:
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Transfer Stations\WasteTransferStations_Baden-Wurttemberg.csv with state name: Baden-Wurttemberg
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Transfer Stations\WasteTransferStations_Bavaria.csv with state name: Bavaria
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Transfer Stations\WasteTransferStations_Berlin.csv with state name: Berlin
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# ...

# %%
def concatenate_csv_files(csv_paths, output_file):
    complete_df = pd.DataFrame()
    
    for csv_path, state_name in csv_paths.items(): 
        df = pd.read_csv(csv_path)
        complete_df = pd.concat([complete_df, df], ignore_index=True)
        print(f"concatenated state {state_name}")
        
    complete_df.to_csv(output_file, index=False)

# %%
output_file = 'complete_wastetransfercentres.csv'  
concatenate_csv_files(paths, output_file)
# Out:
# concatenated state Baden-Wurttemberg
# concatenated state Bavaria
# concatenated state Berlin
# concatenated state Bradenburg
# concatenated state Bremen
# concatenated state Hamburg
# concatenated state Hesse
# concatenated state LowerSaxony_Niedersachsen
# concatenated state Rhineland-Palatinate
# concatenated state Mecklenburg_Vorpommern
# concatenated state Saarland
# concatenated state Saxony-Anhalt
# concatenated state Schleswig-Holstein
# concatenated state Thuringia
# concatenated state NorthRhine-Westphalia
# concatenated state Saxony
