# %% [markdown]
# # Work 1.0

# %%
import json 
import pandas as pd
import numpy as np

# %%
with open('E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\1-raw data\\Geospatial Data\\waste_disposal\\wastedisposalsites_Saxony-Anhalt_DE-ST.json'
          ,'r', encoding='utf-8') as json_file:
    data = json.load(json_file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# e:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Disposal Centres\work.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell:/e%3A/mygit/Berlin-Chapter-Challenge-Waste-Management/src/data/3-clean%20data/Data_Rework/Geospatial%20Data/Waste%20Disposal%20Centres/work.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> with open('E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\1-raw data\\Geospatial Data\\waste_disposal\\wastedisposalsites_Saxony-Anhalt_DE-ST.json'
#       <a href='vscode-notebook-cell:/e%3A/mygit/Berlin-Chapter-Challenge-Waste-Management/src/data/3-clean%20data/Data_Rework/Geospatial%20Data/Waste%20Disposal%20Centres/work.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a>           ,'r', encoding='utf-8') as json_file:
# ----> <a href='vscode-notebook-cell:/e%3A/mygit/Berlin-Chapter-Challenge-Waste-Management/src/data/3-clean%20data/Data_Rework/Geospatial%20Data/Waste%20Disposal%20Centres/work.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a>     data = json.load(json_file)
#
# File c:\Python311\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File c:\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Python311\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Python311\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
new_data_list = []

for entry in data["elements"]:
    new_entry = {
        **entry.get("tags", {}),  
        "type": entry.get("type", None),  
        "id": entry.get("id", None), 
        "lat": entry.get("lat", None),  
        "lon": entry.get("lon", None), 
    }
    new_data_list.append(new_entry)

# %%
df = pd.DataFrame(new_data_list)

# %%
df.shape
# Out:
# (805, 84)

# %%
columnslist = df.columns

for column in columnslist:
    print(f"'{column}'")
# Out:
# 'amenity'
# 'location'
# 'type'
# 'id'
# 'lat'
# 'lon'
# 'waste'
# 'operator'
# 'access'
# 'ele'
# 'fixme'
# 'recycling:glass'
# 'fee'
# 'waste_basket:excrement_bags'
# 'description'
# 'opening_hours'
# 'name'
# 'collection_times'
# 'recycling:PET'
# 'recycling:cans'
# 'recycling:cardboard'
# 'recycling:clothes'
# 'recycling:glass_bottles'
# 'recycling:paper'
# 'recycling:plastic_bottles'
# 'recycling:plastic_packaging'
# 'recycling:shoes'
# 'recycling:small_appliances'
# 'addr:housenumber'
# 'addr:street'
# 'contact:website'
# 'landuse'
# 'addr:city'
# 'addr:country'
# 'addr:postcode'
# 'barrier'
# 'building'
# 'note'
# 'ISO3166-2'
# 'TMC:cid_58:tabcd_1:Class'
# 'TMC:cid_58:tabcd_1:LCLversion'
# 'TMC:cid_58:tabcd_1:LocationCode'
# 'admin_level'
# 'alt_name:pt'
# 'border_type'
# 'boundary'
# 'de:amtlicher_gemeindeschluessel'
# 'de:regionalschluessel'
# 'name:ar'
# 'name:ca'
# 'name:en'
# 'name:eo'
# 'name:es'
# 'name:fa'
# 'name:fi'
# 'name:fr'
# 'name:hsb'
# 'name:hu'
# 'name:ia'
# 'name:io'
# 'name:it'
# 'name:mk'
# 'name:nds'
# 'name:nl'
# 'name:pl'
# 'name:prefix'
# 'name:pt'
# 'name:ru'
# 'name:sk'
# 'name:sl'
# 'name:sr'
# 'name:th'
# 'name:uk'
# 'name:ur'
# 'name:vo'
# 'name:zh'
# 'name:zh-Hans'
# 'name:zh-Hant'
# 'ref'
# 'ref:nuts:1'
# 'ref:nuts:2'
# 'wikidata'
# 'wikipedia'
# 'land_area'

# %%
df.isnull().sum()
# Out:
# amenity       389
# location      802
# type            0
# id              0
# lat            95
#              ...
# ref:nuts:1    804
# ref:nuts:2    804
# wikidata      803
# wikipedia     803
# land_area     804
# Length: 84, dtype: int64

# %%
new_df = df[['id', 'lat', 'lon']]

# %%
df.head()
# Out:
#           amenity    location  type         id        lat        lon waste
# 0  waste_disposal  overground  node  335776642  54.065608  12.117809   NaN  \
# 1  waste_disposal         NaN  node  460891232  53.303265  12.814519   NaN
# 2  waste_disposal         NaN  node  460891237  53.302844  12.815499   NaN
# 3  waste_disposal         NaN  node  460891244  53.303963  12.815060   NaN
# 4  waste_disposal         NaN  node  460891297  53.303962  12.816871   NaN
#
#   operator access  ele  ... barrier building note border_type name:fi name:uk
# 0      NaN    NaN  NaN  ...     NaN      NaN  NaN         NaN     NaN     NaN  \
# 1      NaN    NaN  NaN  ...     NaN      NaN  NaN         NaN     NaN     NaN
# 2      NaN    NaN  NaN  ...     NaN      NaN  NaN         NaN     NaN     NaN
# 3      NaN    NaN  NaN  ...     NaN      NaN  NaN         NaN     NaN     NaN
# 4      NaN    NaN  NaN  ...     NaN      NaN  NaN         NaN     NaN     NaN
#
#   name:ur name:zh-Hans ref:nuts:2 land_area
# 0     NaN          NaN        NaN       NaN
# 1     NaN          NaN        NaN       NaN
# 2     NaN          NaN        NaN       NaN
# 3     NaN          NaN        NaN       NaN
# 4     NaN          NaN        NaN       NaN
#
# [5 rows x 45 columns]

# %%
df.isnull().sum()
# Out:
# amenity                        389
# location                       802
# type                             0
# id                               0
# lat                             95
# lon                             95
# waste                          718
# operator                       796
# access                         686
# ele                            804
# fixme                          804
# recycling:glass                803
# fee                            804
# waste_basket:excrement_bags    804
# description                    802
# opening_hours                  804
# name                           796
# collection_times               804
# recycling:PET                  804
# recycling:cans                 804
# recycling:cardboard            804
# recycling:clothes              804
# recycling:glass_bottles        804
# recycling:paper                804
# recycling:plastic_bottles      804
# recycling:plastic_packaging    804
# recycling:shoes                804
# recycling:small_appliances     804
# addr:housenumber               804
# addr:street                    803
# contact:website                804
# landuse                        804
# addr:city                      804
# addr:country                   804
# addr:postcode                  804
# barrier                        803
# building                       804
# note                           802
# border_type                    804
# name:fi                        804
# name:uk                        804
# name:ur                        804
# name:zh-Hans                   804
# ref:nuts:2                     804
# land_area                      804
# dtype: int64

# %%
new_df.dropna(subset=['lat', 'lon'], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3328\1196869661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.dropna(subset=['lat', 'lon'], inplace=True)

# %%
new_df.to_csv('WasteDisposalCentres__Mecklenburg_Vorpommern_DE-MV.csv', index=False)

# %% [markdown]
# # Work 2.0

# %%
import pandas as pd
import numpy as np

# %%
columns_to_delete = ['ISO3166-2','opening_hours:summer','nohousenumber','bicycle','roof:height', 'leaf_type', 
    'postal_code','location', 'check_date:recycling', 'highway', 'surface', 'covered', 'indoor', 'building',
    'fixme', 'contact:email', 'contact:phone', 'contact:website', 'operator:short', 'addr:suburb',
    'is_in', 'colour', 'brand', 'brand:wikidata', 'ref', 'fax', 'ele', 'internet', 'source:operator',
    'name:de', 'source:ref', 'opening_hours:problematic_waste', 'name:signed', 'opening_hours:url',
    'underground', 'source:amenity', 'description:de','opening_hours:signed', 'note:position','man_made',
    'park_ride','operator:mobile','fence_type','roof:shape','source:outline',
    'toilets:wheelchair','charge','manufacturer','source:opening_hours','payment:credit_cards','official_name:de','long_name',
    'payment:debit_cards','payment:maestro','payment:notes',
    'generator:method','generator:output:electricity','generator:source','height','area','fence','roof:colour','operator:fax',
    'opening_hours:text','object:city','object:postcode','object:street','building:colour','building:material','roof:material',
    'roof:levels','payment:cash','description:en','leaf_type''roof:height','building_1','building:levels','parking',
    'fenced','owner','leisure','note:de', 'alt_name','source:position', 'short_name',
    'power', 'surveillance', 'glasstype', 'operator:email','operator:phone', 'start_date', 'wheelchair:description',
    'source:date','wikipedia','level','contact:fax','video','contact:mobile',
    'barrier','landuse','name:es','name:fr','layer','lit','inscription',
    'oper', 'operator:signed', 'operator:website',
    'check_date:surface','not:brand:wikidata','noname', 'opening_hours:winter','amenity','check_date','addr:city',
    'addr:country','addr:housenumber',
    'addr:postcode','FIXME','check_date:opening_hours','operator','source','description','operator:wikidata',
    'operator:wikipedia','direction','wheelchair','addr:street','website','addr:place',
    'addr:housename','shop','url',
    'brand:wikipedia',
    'checked',
    'damage:event', 'demolished:tourism', 'old_name', 'recycling:batteries',
    'recycling:cans', 'recycling:cardboard', 'recycling:clothes', 'recycling:electrical_appliances',
    'recycling:glass_bottles', 'recycling:green_waste', 'recycling:paper', 'recycling:plastic',
    'recycling:plastic_bottles', 'recycling:plastic_packaging', 'recycling:scrap_metal', 'recycling:shoes',
    'recycling:small_appliances', 'recycling:waste', 'recycling:white_goods', 'recycling:glass',
    'recycling:wood', 'recycling:construction_waste', 'disused:landuse', 'disused', 'storage',
    'visibility', 'service', 'informal', 'natural', 'recycling:garden_waste', 'landfill:waste', 'waste',
    'foot', 'motorcar', 'motorcycle', 'motor_vehicle', 'recycling:electrical_appliances',
    'recycling:small_electrical_appliances', 'generator:type', 'landfill:waste', 'old_name', 'natural',
    'disused', 'alt_name:pt', 'name:nds', 'name:zh-Hans', 'name:zh-Hant', 'foot', 'motorcar', 'motorcycle',
    'depth', 'headframe', 'mineshaft:wikidata', 'mineshaft_type', 'disused', 'landfill:waste', 'recycling:soil',
    'old_name', 'product', 'natural', 'historic', 'collection_times', 'recycling:batteries',
    'recycling:electrical_appliances', 'recycling:green_waste', 'recycling:paper', 'recycling:plastic_packaging',
    'recycling:scrap_metal', 'recycling:small_appliances', 'recycling:waste', 'contaminated', 'step_count',
    'recycling:cans', 'recycling:clothes', 'recycling:clothes', 'recycling:glass', 'recycling:garden_waste',
    'recycling:wood', 'payment:coins', 'payment:cryptocurrencies', 'payment:electronic_purses',
    'recycling:hardcore', 'name:pfl', 'name:tzl', 'foot', 'seats', 'maxspeed', 'traffic_sign', 'motorcar',
    'motorcycle', 'locked','material','loc_ref','name:en','email','note:operator','last_check','note:opening_hours',
    'opening_hours:covid19','image','recycling:de','brand:short','wikimedia_commons','access','mapillary','last_checked',
    'operator:type','note','survey:date','name','created_by','opening_hours','phone','recycling_type',
    'type','resource','coat_of_arms','flag','nickname','nickname:ar','nickname:cs','nickname:de','nickname:en','nickname:eo','nickname:fr',
'nickname:fy','nickname:hsb','nickname:hu','nickname:la','nickname:nds','nickname:fy','nickname:hsb','nickname:hu','nickname:la','nickname:nds','nickname:pl',
'nickname:ru','official_name:eo','official_name:fr','official_name:fy',
'official_name:hsb','official_name:hu','official_name:la','official_name:nds','official_name:pl','official_name:ru','ref:nuts:2','direction_west',
'support',
    'contact:city',
    'contact:housenumber',
    'contact:postcode',
    'contact:street',
    'admin_level',
    'alt_name:eo',
    'border_type','designation',
    'hiking',
    'information',
    'map_size',
    'map_type',
    'mtb',
    'tourism',
    'boundary',
    'TMC:cid_58:tabcd_1:Class',
    'TMC:cid_58:tabcd_1:LCLversion',
    'TMC:cid_58:tabcd_1:LocationCode','de:amtlicher_gemeindeschluessel',
    'de:regionalschluessel',
    'int_name',
    'name:af',
    'name:am',
    'name:an',
    'name:ar',
    'name:ay',
    'name:az',
    'name:ba',
    'name:be',
    'name:bg',
    'name:bn',
    'name:br',
    'name:bs',
    'name:ca',
    'name:ce',
    'name:cs',
    'name:cv',
    'name:cy',
    'name:el',
    'name:eo',
    'name:et',
    'name:eu',
    'name:fa',
    'name:fi',
    'name:fy',
    'name:ga',
    'name:gd',
    'name:gl',
    'name:gn',
    'name:gv',
    'name:he',
    'name:hi',
    'name:hr',
    'name:hsb',
    'name:hu',
    'name:hy',
    'name:ia',
    'name:ie',
    'name:io',
    'name:is',
    'name:it',
    'name:ja',
    'name:ka',
    'name:kg',
    'name:kk',
    'name:ko',
    'name:ky',
    'name:la',
    'name:li',
    'name:lt',
    'name:lv',
    'name:mk',
    'name:ml',
    'name:mn',
    'name:mr',
    'name:ms',
    'name:mt',
    'name:nl',
    'name:oc',
    'name:os',
    'name:pa',
    'name:pl',
    'name:prefix',
    'name:pt',
    'name:rm',
    'name:ro',
    'name:ru',
    'name:sc',
    'name:sk',
    'name:sl',
    'name:sq',
    'name:sr',
    'name:sw',
    'name:szl',
    'name:ta',
    'name:te',
    'name:th',
    'name:tk',
    'name:tl',
    'logo', 'nickname:pt', 'official_name:pt', 'official_status',
    'official_status:ar', 'official_status:de', 'official_status:en', 'official_status:ru',
    'ref:LOCODE', 'ref:nuts:3', 'de:name_index_city', 'de:place', 'name:prefix:de', 'content',
    'addr:inclusion', 'recycling:building', 'alt_name:vi', 'contact:facebook', 'de:place',
    'geographical_region', 'license_plate_code', 'name:als', 'name:ang', 'name:arc', 'name:ast',
    'name:bar', 'name:bat-smg', 'name:be-tarask', 'name:bi', 'name:bo', 'name:cbk-zam', 'name:crh',
    'name:csb', 'name:cu', 'name:da', 'name:diq', 'name:dsb', 'name:fo', 'name:frp', 'name:fur',
    'name:haw', 'name:ht', 'name:id', 'name:ilo', 'name:jbo', 'name:jv', 'name:kab', 'name:ksh',
    'name:ku', 'name:kv', 'name:kw', 'name:lb', 'name:lg', 'name:lij', 'name:lmo', 'name:ln',
    'name:lzh', 'name:mg', 'name:myv', 'name:na', 'name:nah', 'name:nan', 'name:nap', 'name:nn',
    'name:no', 'name:nov', 'name:nrm', 'name:pam', 'name:pdc', 'name:pms', 'name:prefix:city',
    'name:prefix:state', 'name:qu', 'name:rmy', 'name:roa-rup', 'name:roa-tara', 'name:sah',
    'name:scn', 'name:sco', 'name:se', 'name:sh', 'name:short', 'name:so', 'name:stq', 'name:su',
    'name:sv', 'name:tet', 'name:tg', 'name:tpi', 'name:ty', 'name:vec', 'name:vi', 'name:vls',
    'name:wo', 'name:yue', 'name:zu', 'official_status', 'official_status:de', 'official_status:en',
    'official_status:ru', 'old_name:vi', 'place', 'population', 'ref:nuts:3', 'report_problems:website',
    'source:population', 'state_code',
    'recycling:others', 'recycling:rubble', 'lastcheck', 'loc_name', 'recycling:aluminium',
    'recycling:cds', 'recycling:earth', 'recycling:electrical_items', 'recycling:electronic',
    'recycling:electronic_scrap', 'recycling:electronics', 'recycling:tires', 'disused:amenity',
    'disused:opening_hours', 'disused:recycling:hardcore', 'disused:recycling:others',
    'disused:recycling:rubble', 'disused:recycling_type', 'recycling:hardcode', 'source:addr',
    'abandoned', 'source:geometry', 'recycling:organic', 'BBP', 'old_operator', 'crop',
    'old_short_name', 'old_highway', 'capacity', 'abandoned:landuse', 'alt_name:cs', 'name:gsw',
    'name:ps', 'vehicle', 'emergency', 'gate:type', 'entrance', 'goods', 'hgv', 'horse','name:tr',
    'name:tt',
    'name:uk',
    'name:ur',
    'name:uz',
    'name:vo',
    'name:yi',
    'name:yo',
    'name:zh','land_area',
    'official_name',
    'official_name:ar',
    'official_name:cs',
    'official_name:en',
    'official_name:sk',
    'official_name:sr',
'old_name:cs','military',
'landfill:class',
'comment','landfill',
'waterway',
'alt_name:ca',
    'ref:nuts',
    'ref:nuts:1',
    'wikidata',]

# %%
def delete_columns(df, columns_to_delete):
    for column in columns_to_delete:
        if column in df.columns:
            df.drop(column, axis=1, inplace=True)
    return df

# %%
paths = {
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Baden-Wurttemberg_DE-BW.csv" : "Baden-Wurttemberg", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Bavaria.csv" : "Bavaria", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Berlin.csv" : "Berlin", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Bradenburg.csv" : "Bradenburg", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Bremen.csv" : "Bremen", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Hamburg.csv" : "Hamburg", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Hesse(DE-HE).csv" : "Hesse", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_LowerSaxony_Niedersachsen_DE-NI.csv" : "LowerSaxony_Niedersachsen", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Rhineland-Palatinate.csv" : "Rhineland-Palatinate", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Mecklenburg_Vorpommern_DE-MV.csv" : "Mecklenburg_Vorpommern", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Saarland(DE-SL).csv" : "Saarland", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Saxony-Anhalt_DE-ST.csv" : "Saxony-Anhalt", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Saxony(DE-SN).csv" : "Saxony", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Schleswig-Holstein_DE-SH.csv" : "Schleswig-Holstein", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_Thuringia.csv" : "Thuringia", 
    "E:\\mygit\\Berlin-Chapter-Challenge-Waste-Management\\src\\data\\3-clean data\\Data_Rework\\Geospatial Data\\Waste Disposal Centres\\WasteDisposalCentres_NorthRhine-Westphalia.csv" : "NorthRhine-Westphalia", 
   
    }

# %%
def add_state(paths):
    for file_path, state_name in paths.items():  
        try:
            df = pd.read_csv(file_path)
            df['state'] = state_name
            df['station'] = "waste disposal centres"
            df = delete_columns(df, columns_to_delete) 

            column_list = df.columns
            print("........")
            for column in column_list:
                
                print(f"'{column}',")
            
            df.to_csv(file_path, index=False)
            
            print(f"Added 'state' column to {file_path} with state name: {state_name}")
        except Exception as e:
            print(f"Error processing {file_path}: {str(e)}")

# %%
add_state(paths)
# Out:
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Disposal Centres\WasteDisposalCentres_Hesse(DE-HE).csv with state name: Hesse
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Disposal Centres\WasteDisposalCentres_LowerSaxony_Niedersachsen_DE-NI.csv with state name: LowerSaxony_Niedersachsen
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Disposal Centres\WasteDisposalCentres_Rhineland-Palatinate.csv with state name: Rhineland-Palatinate
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Disposal Centres\WasteDisposalCentres_Mecklenburg_Vorpommern_DE-MV.csv with state name: Mecklenburg_Vorpommern
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Disposal Centres\WasteDisposalCentres_Saarland(DE-SL).csv with state name: Saarland
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Disposal Centres\WasteDisposalCentres_Saxony-Anhalt_DE-ST.csv with state name: Saxony-Anhalt
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Disposal Centres\WasteDisposalCentres_Saxony(DE-SN).csv with state name: Saxony
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Disposal Centres\WasteDisposalCentres_Schleswig-Holstein_DE-SH.csv with state name: Schleswig-Holstein
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Disposal Centres\WasteDisposalCentres_Thuringia.csv with state name: Thuringia
# ........
# 'id',
# 'lat',
# 'lon',
# 'state',
# 'station',
# Added 'state' column to E:\mygit\Berlin-Chapter-Challenge-Waste-Management\src\data\3-clean data\Data_Rework\Geospatial Data\Waste Disposal Centres\WasteDisposalCentres_NorthRhine-Westphalia.csv with state name: NorthRhine-Westphalia

# %%
def concatenate_csv_files(csv_paths, output_file):
    complete_df = pd.DataFrame()
    
    for csv_path, _ in csv_paths.items(): 
        df = pd.read_csv(csv_path)
        complete_df = pd.concat([complete_df, df], ignore_index=True)
        
    complete_df.to_csv(output_file, index=False)

# %%
output_file = 'complete_wastedisposalcentres.csv'  
concatenate_csv_files(paths, output_file)
