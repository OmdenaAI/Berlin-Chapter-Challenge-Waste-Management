# %%
import pandas as pd 
import pygwalker as pyg

# %%
df = pd.read_csv('Processed_DatasetsAmount-of Waste-Generated-By-State 32121-0003.csv',sep=',',encoding='latin1')
df1 = pd.read_csv('Amount-of Waste-Generated-By-State 32121-0003.csv',sep=',',encoding='latin1')

# %%
df.head()
# Error in naming don't  use processed one
# Out:
#    Year              States                       Types of Waste  \
# 0  2004  Baden-WÃ¼rttemberg  Residual household and bulky wastes
# 1  2004  Baden-WÃ¼rttemberg  Separately collected organic wastes
# 2  2004  Baden-WÃ¼rttemberg     Separately collected recyclables
# 3  2004  Baden-WÃ¼rttemberg                         Other wastes
# 4  2004              Bayern  Separately collected organic wastes
#
#    Total Household Waste Generated (Tons)  \
# 0                                  1605.6
# 1                                  1220.5
# 2                                  1645.3
# 3                                     9.4
# 4                                  1677.3
#
#    Household Waste Generated per Inhabitant (kg)
# 0                                          150.0
# 1                                          114.0
# 2                                          154.0
# 3                                            1.0
# 4                                          135.0

# %%
df1.head()
# Out:
#    Year             States                       Types of Waste  \
# 0  2004  Baden-Württemberg  Residual household and bulky wastes
# 1  2004  Baden-Württemberg  Separately collected organic wastes
# 2  2004  Baden-Württemberg     Separately collected recyclables
# 3  2004  Baden-Württemberg                         Other wastes
# 4  2004             Bayern  Residual household and bulky wastes
#
#    Amount of Household Wastes Generated (1000 t)  \
# 0                                         1605.6
# 1                                         1220.5
# 2                                         1645.3
# 3                                            9.4
# 4                                         2039.5
#
#    Amount of Household Wastes Generated p. Inhabitant (kg)
# 0                                                150
# 1                                                114
# 2                                                154
# 3                                                  1
# ...

# %%
pyg.walk(df1,dark='dark')
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-1" style="height: auto">\n    <head>\n        <meta http-equiv="Con…
# <html>
# <style>
# .tabs{
#     position:relative;
#     height:660px;
# }
# .tab-pane{
#     display:inline-block;
# }
# .tabs input[type='radio']{
#     position:absolute;
#     clip:rect(0,0,0,0)
# }
# .tab-item{
#     display:block;
#     height:34px;
#     line-height:34px;
#     cursor:pointer;
#     padding:0 10px
# }
#
# .tabs input[type='radio']:checked+.tab-item{
#     background:#2563eb;
#     color:#fff
# }
#
# .tab-content{
#     display: none;
#     position:absolute;
#     left:0;
#     top:56px;
#     bottom:0;
#     right:0;
# }
#
# .tabs input[type='radio']:checked+.tab-item+.tab-content{
#     display: block;
# }
# </style>
#
# <body>
#     <div id="pygwalker-preview-1">
#         <div class="tabs">
#
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# ## Inferences
# 1) Residual household waste seems to be the dominant waste type followed by recylables
# 2) Year wise Trend also suggests the same thing
# 3) For State wise Analysis we can see that Nordrhein-Westfalen has the maximum amount of waste produced in terms of waste generated by household
# 4) For waste generated by individual most states have relatively same amount suggesting on average 400 kg (maxminum) of waste is produced  with the exception of  Sachsen

# %%
df['States'].unique()
# Out:
# array(['Baden-WÃ¼rttemberg', 'Bayern', 'Berlin', 'Brandenburg', 'Bremen',
#        'Hamburg', 'Hessen', 'Mecklenburg-Vorpommern', 'Niedersachsen',
#        'Nordrhein-Westfalen', 'Rheinland-Pfalz', 'Saarland', 'Sachsen',
#        'Sachsen-Anhalt', 'Schleswig-Holstein', 'ThÃ¼ringen'], dtype=object)

# %%
#  Run this code to see the dashboard
vis_spec = r"""{"config":"[{\"visId\":\"gw_Pycn\",\"name\":\"Average waste produced depending on type\",\"encodings\":{\"dimensions\":[{\"dragId\":\"gw_YD-d\",\"fid\":\"GW_YUAPC0YLS\",\"name\":\"Year\",\"basename\":\"Year\",\"semanticType\":\"ordinal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_Ji0J\",\"fid\":\"GW_19ORPIAAE8H80\",\"name\":\"States\",\"basename\":\"States\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_2RL9\",\"fid\":\"GW_501EQ4G4DXRQQHKOWPB2CQ4VK\",\"name\":\"Types of Waste\",\"basename\":\"Types of Waste\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"measures\":[{\"dragId\":\"gw_jKaY\",\"fid\":\"GW_3H49EDPKB70NJDLIS1Q2BRQL7PIJ7XJAU3P8ZNNUKBH1IWI6M2N4S764VQMA1C6A23OR0GLYO\",\"name\":\"Amount of Household Wastes Generated (1000 t)\",\"basename\":\"Amount of Household Wastes Generated (1000 t)\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_XDBy\",\"fid\":\"GW_J077GM6EP734G3HKFRDCGXCCHSX8ADUL5I0L05922YWBPZSXHYFMZ0VPWWHIDJRBCUA8SOEAUQ6CSCAXR2UZO94G\",\"name\":\"Amount of Household Wastes Generated p. Inhabitant (kg)\",\"basename\":\"Amount of Household Wastes Generated p. Inhabitant (kg)\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_count_fid\",\"fid\":\"gw_count_fid\",\"name\":\"Row count\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\",\"computed\":true,\"expression\":{\"op\":\"one\",\"params\":[],\"as\":\"gw_count_fid\"}}],\"rows\":[{\"dragId\":\"gw_btG6\",\"fid\":\"GW_501EQ4G4DXRQQHKOWPB2CQ4VK\",\"name\":\"Types of Waste\",\"basename\":\"Types of Waste\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"columns\":[{\"dragId\":\"gw_69KL\",\"fid\":\"GW_3H49EDPKB70NJDLIS1Q2BRQL7PIJ7XJAU3P8ZNNUKBH1IWI6M2N4S764VQMA1C6A23OR0GLYO\",\"name\":\"Amount of Household Wastes Generated (1000 t)\",\"basename\":\"Amount of Household Wastes Generated (1000 t)\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"mean\"}],\"color\":[{\"dragId\":\"gw_NWKd\",\"fid\":\"GW_501EQ4G4DXRQQHKOWPB2CQ4VK\",\"name\":\"Types of Waste\",\"basename\":\"Types of Waste\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"opacity\":[],\"size\":[],\"shape\":[],\"radius\":[],\"theta\":[],\"longitude\":[],\"latitude\":[],\"geoId\":[],\"details\":[],\"filters\":[],\"text\":[]},\"config\":{\"defaultAggregated\":true,\"geoms\":[\"auto\"],\"showTableSummary\":false,\"coordSystem\":\"generic\",\"stack\":\"stack\",\"showActions\":false,\"interactiveScale\":false,\"sorted\":\"none\",\"zeroScale\":true,\"scaleIncludeUnmatchedChoropleth\":false,\"size\":{\"mode\":\"auto\",\"width\":320,\"height\":200},\"format\":{},\"geoKey\":\"name\",\"resolve\":{\"x\":false,\"y\":false,\"color\":false,\"opacity\":false,\"shape\":false,\"size\":false},\"limit\":-1}},{\"visId\":\"gw_gV9n\",\"name\":\"Year wise analysis\",\"encodings\":{\"dimensions\":[{\"dragId\":\"gw_s7Ux\",\"fid\":\"GW_YUAPC0YLS\",\"name\":\"Year\",\"basename\":\"Year\",\"semanticType\":\"ordinal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_-SN7\",\"fid\":\"GW_19ORPIAAE8H80\",\"name\":\"States\",\"basename\":\"States\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_JBeR\",\"fid\":\"GW_501EQ4G4DXRQQHKOWPB2CQ4VK\",\"name\":\"Types of Waste\",\"basename\":\"Types of Waste\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"measures\":[{\"dragId\":\"gw_CQ87\",\"fid\":\"GW_3H49EDPKB70NJDLIS1Q2BRQL7PIJ7XJAU3P8ZNNUKBH1IWI6M2N4S764VQMA1C6A23OR0GLYO\",\"name\":\"Amount of Household Wastes Generated (1000 t)\",\"basename\":\"Amount of Household Wastes Generated (1000 t)\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_TTZh\",\"fid\":\"GW_J077GM6EP734G3HKFRDCGXCCHSX8ADUL5I0L05922YWBPZSXHYFMZ0VPWWHIDJRBCUA8SOEAUQ6CSCAXR2UZO94G\",\"name\":\"Amount of Household Wastes Generated p. Inhabitant (kg)\",\"basename\":\"Amount of Household Wastes Generated p. Inhabitant (kg)\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_count_fid\",\"fid\":\"gw_count_fid\",\"name\":\"Row count\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\",\"computed\":true,\"expression\":{\"op\":\"one\",\"params\":[],\"as\":\"gw_count_fid\"}}],\"rows\":[{\"dragId\":\"gw__HJn\",\"fid\":\"GW_3H49EDPKB70NJDLIS1Q2BRQL7PIJ7XJAU3P8ZNNUKBH1IWI6M2N4S764VQMA1C6A23OR0GLYO\",\"name\":\"Amount of Household Wastes Generated (1000 t)\",\"basename\":\"Amount of Household Wastes Generated (1000 t)\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"mean\"},{\"dragId\":\"gw_xkfZ\",\"fid\":\"GW_J077GM6EP734G3HKFRDCGXCCHSX8ADUL5I0L05922YWBPZSXHYFMZ0VPWWHIDJRBCUA8SOEAUQ6CSCAXR2UZO94G\",\"name\":\"Amount of Household Wastes Generated p. Inhabitant (kg)\",\"basename\":\"Amount of Household Wastes Generated p. Inhabitant (kg)\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"mean\"}],\"columns\":[{\"dragId\":\"gw_oqk0\",\"fid\":\"GW_YUAPC0YLS\",\"name\":\"Year\",\"basename\":\"Year\",\"semanticType\":\"ordinal\",\"analyticType\":\"dimension\"}],\"color\":[{\"dragId\":\"gw__RHz\",\"fid\":\"GW_501EQ4G4DXRQQHKOWPB2CQ4VK\",\"name\":\"Types of Waste\",\"basename\":\"Types of Waste\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"opacity\":[],\"size\":[],\"shape\":[],\"radius\":[],\"theta\":[],\"longitude\":[],\"latitude\":[],\"geoId\":[],\"details\":[],\"filters\":[],\"text\":[]},\"config\":{\"defaultAggregated\":true,\"geoms\":[\"auto\"],\"showTableSummary\":false,\"coordSystem\":\"generic\",\"stack\":\"stack\",\"showActions\":false,\"interactiveScale\":false,\"sorted\":\"none\",\"zeroScale\":true,\"scaleIncludeUnmatchedChoropleth\":false,\"size\":{\"mode\":\"auto\",\"width\":320,\"height\":200},\"format\":{},\"geoKey\":\"name\",\"resolve\":{\"x\":false,\"y\":false,\"color\":false,\"opacity\":false,\"shape\":false,\"size\":false},\"limit\":-1}},{\"visId\":\"gw_ZUkT\",\"name\":\"Chart 3\",\"encodings\":{\"dimensions\":[{\"dragId\":\"gw_fY3w\",\"fid\":\"GW_YUAPC0YLS\",\"name\":\"Year\",\"basename\":\"Year\",\"semanticType\":\"ordinal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_aouH\",\"fid\":\"GW_19ORPIAAE8H80\",\"name\":\"States\",\"basename\":\"States\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_cFEA\",\"fid\":\"GW_501EQ4G4DXRQQHKOWPB2CQ4VK\",\"name\":\"Types of Waste\",\"basename\":\"Types of Waste\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"measures\":[{\"dragId\":\"gw_-DKi\",\"fid\":\"GW_3H49EDPKB70NJDLIS1Q2BRQL7PIJ7XJAU3P8ZNNUKBH1IWI6M2N4S764VQMA1C6A23OR0GLYO\",\"name\":\"Amount of Household Wastes Generated (1000 t)\",\"basename\":\"Amount of Household Wastes Generated (1000 t)\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_2Bbg\",\"fid\":\"GW_J077GM6EP734G3HKFRDCGXCCHSX8ADUL5I0L05922YWBPZSXHYFMZ0VPWWHIDJRBCUA8SOEAUQ6CSCAXR2UZO94G\",\"name\":\"Amount of Household Wastes Generated p. Inhabitant (kg)\",\"basename\":\"Amount of Household Wastes Generated p. Inhabitant (kg)\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_count_fid\",\"fid\":\"gw_count_fid\",\"name\":\"Row count\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\",\"computed\":true,\"expression\":{\"op\":\"one\",\"params\":[],\"as\":\"gw_count_fid\"}}],\"rows\":[{\"dragId\":\"gw_CCex\",\"fid\":\"GW_3H49EDPKB70NJDLIS1Q2BRQL7PIJ7XJAU3P8ZNNUKBH1IWI6M2N4S764VQMA1C6A23OR0GLYO\",\"name\":\"Amount of Household Wastes Generated (1000 t)\",\"basename\":\"Amount of Household Wastes Generated (1000 t)\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_R_j4\",\"fid\":\"GW_J077GM6EP734G3HKFRDCGXCCHSX8ADUL5I0L05922YWBPZSXHYFMZ0VPWWHIDJRBCUA8SOEAUQ6CSCAXR2UZO94G\",\"name\":\"Amount of Household Wastes Generated p. Inhabitant (kg)\",\"basename\":\"Amount of Household Wastes Generated p. Inhabitant (kg)\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"}],\"columns\":[{\"dragId\":\"gw_gD3A\",\"fid\":\"GW_19ORPIAAE8H80\",\"name\":\"States\",\"basename\":\"States\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"color\":[{\"dragId\":\"gw_HiZf\",\"fid\":\"GW_501EQ4G4DXRQQHKOWPB2CQ4VK\",\"name\":\"Types of Waste\",\"basename\":\"Types of Waste\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"opacity\":[],\"size\":[],\"shape\":[],\"radius\":[],\"theta\":[],\"longitude\":[],\"latitude\":[],\"geoId\":[],\"details\":[],\"filters\":[],\"text\":[]},\"config\":{\"defaultAggregated\":true,\"geoms\":[\"auto\"],\"showTableSummary\":false,\"coordSystem\":\"generic\",\"stack\":\"stack\",\"showActions\":false,\"interactiveScale\":false,\"sorted\":\"none\",\"zeroScale\":true,\"scaleIncludeUnmatchedChoropleth\":false,\"size\":{\"mode\":\"auto\",\"width\":320,\"height\":200},\"format\":{},\"geoKey\":\"name\",\"resolve\":{\"x\":false,\"y\":false,\"color\":false,\"opacity\":false,\"shape\":false,\"size\":false},\"limit\":-1}}]","chart_map":{},"version":"0.3.7"}"""
pyg.walk(df1, spec=vis_spec, dark='dark')
# Out:
# WARNING: parse invoke code failed, This may affect feature of export code.
# Box(children=(HTML(value='<div id="ifr-pyg-4" style="height: auto">\n    <head>\n        <meta http-equiv="Con…
# <html>
# <style>
# .tabs{
#     position:relative;
#     height:660px;
# }
# .tab-pane{
#     display:inline-block;
# }
# .tabs input[type='radio']{
#     position:absolute;
#     clip:rect(0,0,0,0)
# }
# .tab-item{
#     display:block;
#     height:34px;
#     line-height:34px;
#     cursor:pointer;
#     padding:0 10px
# }
#
# .tabs input[type='radio']:checked+.tab-item{
#     background:#2563eb;
#     color:#fff
# }
#
# .tab-content{
#     display: none;
#     position:absolute;
#     left:0;
#     top:56px;
#     bottom:0;
#     right:0;
# }
#
# .tabs input[type='radio']:checked+.tab-item+.tab-content{
#     display: block;
# }
# </style>
#
# <body>
#     <div id="pygwalker-preview-4">
#         <div class="tabs">
#
#             <div class="tab-pane">
#
# ...
