# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install pygwalker
import pygwalker as pyg
import pandas as pd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 41.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 964.4/964.4 kB 41.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 57.9 MB/s eta 0:00:00:00:0100:01
# ...

# %%
data = pd.read_csv("/kaggle/input/waste-generated-0004/waste_generated_32161-0004.csv")

# %%
data.head()
# Out:
#    Year     data_belong_to  Local units  Quantity of waste produced
# 0  2010  Baden-Württemberg         3471                      7251.4
# 1  2010             bayern         3280                      8768.5
# 2  2010             Berlin          474                      1682.6
# 3  2010        Brandenburg          429                      2765.1
# 4  2010             Bremen          139                       358.1

# %% [markdown]
# 1. Year: This column represents the year for which the waste production data is recorded.
#
# 2. data_belong_to: This column likely represents the geographical or administrative regions or areas to which the waste production data belongs. Each row in this column specifies the region or area associated with the corresponding waste production quantity.
#
# 3. Local units: This column seems to contain information about the local units or entities within the specified regions or areas. These local units could be municipalities, districts, or other administrative divisions. The numbers in this column indicate the count of local units in each region or area.
#
# 4. Quantity of waste produced: It represents the quantity of waste produced in each of the local units. The values in this column likely represent waste production quantities in some unit of measurement (e.g., tons, kilograms).
#
# In summary, the dataset appears to provide waste production data for the year 2010, broken down by geographical or administrative regions (data_belong_to), the number of local units within each region, and the corresponding quantity of waste produced in those local units. This data can be used to analyze and compare waste production across different regions or areas.

# %%
walker5 = pyg.walk(
    data,
    spec="./gw0.json",       # this json will save your chart state, you need to click save button in ui mannual when you finish a chart, 'autosave' will be supported in the future.
    use_kernel_calc=True,    # set `use_kernel_calc=True`, pygwalker will use duckdb as computing engine, it support you explore bigger dataset(<=100GB).
    use_preview=True,         # set `use_kernel_calc=True`, pygwalker will use duckdb as computing engine, it support you explore bigger dataset(<=100GB).
)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-0" style="height: auto">\n    <head>\n        <meta http-equiv="Con…
# <html>
# <style>
# .tabs{
#     position:relative;
#     height:660px;
# }
# .tab-pane{
#     display:inline-block;
# }
# .tabs input[type='radio']{
#     position:absolute;
#     clip:rect(0,0,0,0)
# }
# .tab-item{
#     display:block;
#     height:34px;
#     line-height:34px;
#     cursor:pointer;
#     padding:0 10px
# }
#
# .tabs input[type='radio']:checked+.tab-item{
#     background:#2563eb;
#     color:#fff
# }
#
# .tab-content{
#     display: none;
#     position:absolute;
#     left:0;
#     top:56px;
#     bottom:0;
#     right:0;
# }
#
# .tabs input[type='radio']:checked+.tab-item+.tab-content{
#     display: block;
# }
# </style>
#
# <body>
#     <div id="pygwalker-preview-0">
#         <div class="tabs">
#
#             <div class="tab-pane">
#
#                 <input type="radio" name="tab-pyg-0" id="tab-0-Chart4" checked />
#
# ...
