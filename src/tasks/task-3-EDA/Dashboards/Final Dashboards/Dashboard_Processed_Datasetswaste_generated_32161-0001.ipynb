# %%
# !pip install pygwalker
# Out:
# Collecting pygwalker
#   Using cached pygwalker-0.3.7-py3-none-any.whl (1.2 MB)
# Requirement already satisfied: requests in c:\users\rupas\anaconda3\lib\site-packages (from pygwalker) (2.27.1)
# Requirement already satisfied: sqlalchemy in c:\users\rupas\anaconda3\lib\site-packages (from pygwalker) (1.4.32)
# Requirement already satisfied: psutil in c:\users\rupas\anaconda3\lib\site-packages (from pygwalker) (5.8.0)
# Collecting astor
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: jinja2 in c:\users\rupas\anaconda3\lib\site-packages (from pygwalker) (2.11.3)
# Collecting duckdb
#   Downloading duckdb-0.9.0-cp39-cp39-win_amd64.whl (10.3 MB)
# Collecting sqlglot
#   Downloading sqlglot-18.11.6-py3-none-any.whl (315 kB)
# Collecting gw-dsl-parser==0.1.6a1
#   Using cached gw_dsl_parser-0.1.6a1-py3-none-any.whl (964 kB)
# Requirement already satisfied: ipywidgets in c:\users\rupas\anaconda3\lib\site-packages (from pygwalker) (7.6.5)
# Requirement already satisfied: ipython in c:\users\rupas\anaconda3\lib\site-packages (from pygwalker) (8.2.0)
# Requirement already satisfied: typing-extensions in c:\users\rupas\anaconda3\lib\site-packages (from pygwalker) (4.1.1)
# Collecting pyarrow
#   Downloading pyarrow-13.0.0-cp39-cp39-win_amd64.whl (24.4 MB)
# Collecting pydantic
#   Using cached pydantic-2.4.2-py3-none-any.whl (395 kB)
# Requirement already satisfied: arrow in c:\users\rupas\anaconda3\lib\site-packages (from pygwalker) (1.2.2)
# Collecting wasmtime==12.0.0
#   Using cached wasmtime-12.0.0-py3-none-win_amd64.whl (4.8 MB)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\rupas\anaconda3\lib\site-packages (from arrow->pygwalker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\rupas\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->arrow->pygwalker) (1.16.0)
# Requirement already satisfied: traitlets>=5 in c:\users\rupas\anaconda3\lib\site-packages (from ipython->pygwalker) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\rupas\anaconda3\lib\site-packages (from ipython->pygwalker) (2.11.2)
# Requirement already satisfied: stack-data in c:\users\rupas\anaconda3\lib\site-packages (from ipython->pygwalker) (0.2.0)
# Requirement already satisfied: backcall in c:\users\rupas\anaconda3\lib\site-packages (from ipython->pygwalker) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\rupas\anaconda3\lib\site-packages (from ipython->pygwalker) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\rupas\anaconda3\lib\site-packages (from ipython->pygwalker) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\rupas\anaconda3\lib\site-packages (from ipython->pygwalker) (3.0.20)
# Requirement already satisfied: decorator in c:\users\rupas\anaconda3\lib\site-packages (from ipython->pygwalker) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\rupas\anaconda3\lib\site-packages (from ipython->pygwalker) (61.2.0)
# Requirement already satisfied: colorama in c:\users\rupas\anaconda3\lib\site-packages (from ipython->pygwalker) (0.4.4)
# Requirement already satisfied: matplotlib-inline in c:\users\rupas\anaconda3\lib\site-packages (from ipython->pygwalker) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\rupas\anaconda3\lib\site-packages (from jedi>=0.16->ipython->pygwalker) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\rupas\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->pygwalker) (0.2.5)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\rupas\anaconda3\lib\site-packages (from ipywidgets->pygwalker) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\rupas\anaconda3\lib\site-packages (from ipywidgets->pygwalker) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\rupas\anaconda3\lib\site-packages (from ipywidgets->pygwalker) (6.9.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\rupas\anaconda3\lib\site-packages (from ipywidgets->pygwalker) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\rupas\anaconda3\lib\site-packages (from ipywidgets->pygwalker) (5.3.0)
# Requirement already satisfied: nest-asyncio in c:\users\rupas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pygwalker) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\rupas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pygwalker) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\rupas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pygwalker) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\rupas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pygwalker) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\rupas\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pygwalker) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\rupas\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pygwalker) (4.9.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\rupas\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pygwalker) (302)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\rupas\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pygwalker) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\rupas\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pygwalker) (2.15.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\rupas\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pygwalker) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\rupas\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pygwalker) (0.18.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\rupas\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (6.4.8)
# Requirement already satisfied: nbconvert in c:\users\rupas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\rupas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\rupas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (21.3.0)
# Requirement already satisfied: prometheus-client in c:\users\rupas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (0.13.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\rupas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (0.13.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\rupas\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\rupas\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\rupas\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\rupas\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\rupas\anaconda3\lib\site-packages (from jinja2->pygwalker) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\rupas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\rupas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (0.1.2)
# Requirement already satisfied: bleach in c:\users\rupas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (4.1.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\rupas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\rupas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\rupas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\rupas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\rupas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (4.11.1)
# Requirement already satisfied: testpath in c:\users\rupas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (0.5.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rupas\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (2.3.1)
# Requirement already satisfied: packaging in c:\users\rupas\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (21.3)
# Requirement already satisfied: webencodings in c:\users\rupas\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\rupas\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pygwalker) (3.0.4)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\rupas\anaconda3\lib\site-packages (from pyarrow->pygwalker) (1.21.5)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting typing-extensions
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting pydantic-core==2.10.1
#   Downloading pydantic_core-2.10.1-cp39-none-win_amd64.whl (2.0 MB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rupas\anaconda3\lib\site-packages (from requests->pygwalker) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rupas\anaconda3\lib\site-packages (from requests->pygwalker) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rupas\anaconda3\lib\site-packages (from requests->pygwalker) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\rupas\anaconda3\lib\site-packages (from requests->pygwalker) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rupas\anaconda3\lib\site-packages (from sqlalchemy->pygwalker) (1.1.1)
# Requirement already satisfied: asttokens in c:\users\rupas\anaconda3\lib\site-packages (from stack-data->ipython->pygwalker) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\rupas\anaconda3\lib\site-packages (from stack-data->ipython->pygwalker) (0.2.2)
# Requirement already satisfied: executing in c:\users\rupas\anaconda3\lib\site-packages (from stack-data->ipython->pygwalker) (0.8.3)
# Installing collected packages: typing-extensions, wasmtime, pydantic-core, annotated-types, sqlglot, pydantic, pyarrow, gw-dsl-parser, duckdb, astor, pygwalker
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
# Successfully installed annotated-types-0.6.0 astor-0.8.1 duckdb-0.9.0 gw-dsl-parser-0.1.6a1 pyarrow-13.0.0 pydantic-2.4.2 pydantic-core-2.10.1 pygwalker-0.3.7 sqlglot-18.11.6 typing-extensions-4.8.0 wasmtime-12.0.0

# %%
#import sys
#!(sys.executable) -m pip install pygwalker -g

# %%
import pandas as pd
import pygwalker as pyg

# %%
df=pd.read_csv("C:\\Users\\rupas\\Downloads\\Processed_Datasetswaste_generated_32161-0001.csv")
df.head()
# Out:
#    year                                     types_of_waste  \
# 0  2010           Falls from the extraction of land values
# 1  2010   Cases from dismantling v. metal-rich soil res...
# 2  2010    Cases from dismantling v. non-metal Floor shows
# 3  2010        Acid forming treatment residues a. sul. ore
# 4  2010   Other treatment residues with hazardous subst...
#
#    etroi_establishments_number  generated_waste_quantity
# 0                       2305.0                      23.8
# 1                          3.0                       1.7
# 2                          3.0                      13.7
# 3                       2305.0                      23.8
# 4                       2305.0                      23.8

# %%
pyg.walk(df,dark='dark')
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-1" style="height: auto">\n    <head>\n        <meta http-equiv="Con…
# <html>
# <style>
# .tabs{
#     position:relative;
#     height:660px;
# }
# .tab-pane{
#     display:inline-block;
# }
# .tabs input[type='radio']{
#     position:absolute;
#     clip:rect(0,0,0,0)
# }
# .tab-item{
#     display:block;
#     height:34px;
#     line-height:34px;
#     cursor:pointer;
#     padding:0 10px
# }
#
# .tabs input[type='radio']:checked+.tab-item{
#     background:#2563eb;
#     color:#fff
# }
#
# .tab-content{
#     display: none;
#     position:absolute;
#     left:0;
#     top:56px;
#     bottom:0;
#     right:0;
# }
#
# .tabs input[type='radio']:checked+.tab-item+.tab-content{
#     display: block;
# }
# </style>
#
# <body>
#     <div id="pygwalker-preview-1">
#         <div class="tabs">
#
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# Inferences
# 1.The amount of waste generated in the year 2014 was the highest.
# 2.The number of etroi_establishments were higher in the year 2018
# 3.Paper and Cardboard Packing has the highest number of etroi_establishments at 39735.

# %%
vis_spec = r"""{"config":"[{\"visId\":\"gw_tZcr\",\"name\":\"year Vs generated_waste_quantity\",\"encodings\":{\"dimensions\":[{\"dragId\":\"gw_6PoZ\",\"fid\":\"GW_1BBA6IQGC0\",\"name\":\"year\",\"basename\":\"year\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_4Gmo\",\"fid\":\"GW_6W8NGR74JPZL79YD8TW2IX1DC\",\"name\":\"types_of_waste\",\"basename\":\"types_of_waste\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"measures\":[{\"dragId\":\"gw_teeL\",\"fid\":\"GW_943084LMSK2YLWBT63C7VUGNVJYFLPBU4SKTZMLJJSPIO\",\"name\":\"etroi_establishments_number\",\"basename\":\"etroi_establishments_number\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_MP8T\",\"fid\":\"GW_XH261AU4J9MH4I3XQQL97W5DAYL2R2013ZE1M8TS\",\"name\":\"generated_waste_quantity\",\"basename\":\"generated_waste_quantity\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_count_fid\",\"fid\":\"gw_count_fid\",\"name\":\"Row count\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\",\"computed\":true,\"expression\":{\"op\":\"one\",\"params\":[],\"as\":\"gw_count_fid\"}}],\"rows\":[{\"dragId\":\"gw_nWVD\",\"fid\":\"GW_XH261AU4J9MH4I3XQQL97W5DAYL2R2013ZE1M8TS\",\"name\":\"generated_waste_quantity\",\"basename\":\"generated_waste_quantity\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"}],\"columns\":[{\"dragId\":\"gw_2uwM\",\"fid\":\"GW_1BBA6IQGC0\",\"name\":\"year\",\"basename\":\"year\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"color\":[{\"dragId\":\"gw_CmD-\",\"fid\":\"GW_XH261AU4J9MH4I3XQQL97W5DAYL2R2013ZE1M8TS\",\"name\":\"generated_waste_quantity\",\"basename\":\"generated_waste_quantity\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"}],\"opacity\":[],\"size\":[],\"shape\":[{\"dragId\":\"gw_OJSg\",\"fid\":\"GW_1BBA6IQGC0\",\"name\":\"year\",\"basename\":\"year\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"radius\":[],\"theta\":[],\"longitude\":[],\"latitude\":[],\"geoId\":[],\"details\":[],\"filters\":[],\"text\":[]},\"config\":{\"defaultAggregated\":true,\"geoms\":[\"auto\"],\"showTableSummary\":false,\"coordSystem\":\"generic\",\"stack\":\"stack\",\"showActions\":false,\"interactiveScale\":false,\"sorted\":\"none\",\"zeroScale\":true,\"scaleIncludeUnmatchedChoropleth\":false,\"size\":{\"mode\":\"fixed\",\"width\":451,\"height\":246},\"format\":{},\"geoKey\":\"name\",\"resolve\":{\"x\":false,\"y\":false,\"color\":false,\"opacity\":false,\"shape\":false,\"size\":false},\"limit\":-1}},{\"visId\":\"gw_opgv\",\"name\":\"etroi_establishments_number Vs types_of_waste\",\"encodings\":{\"dimensions\":[{\"dragId\":\"gw_Gp1i\",\"fid\":\"GW_1BBA6IQGC0\",\"name\":\"year\",\"basename\":\"year\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_LcSi\",\"fid\":\"GW_6W8NGR74JPZL79YD8TW2IX1DC\",\"name\":\"types_of_waste\",\"basename\":\"types_of_waste\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"measures\":[{\"dragId\":\"gw_HXTc\",\"fid\":\"GW_943084LMSK2YLWBT63C7VUGNVJYFLPBU4SKTZMLJJSPIO\",\"name\":\"etroi_establishments_number\",\"basename\":\"etroi_establishments_number\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_4Zu9\",\"fid\":\"GW_XH261AU4J9MH4I3XQQL97W5DAYL2R2013ZE1M8TS\",\"name\":\"generated_waste_quantity\",\"basename\":\"generated_waste_quantity\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_count_fid\",\"fid\":\"gw_count_fid\",\"name\":\"Row count\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\",\"computed\":true,\"expression\":{\"op\":\"one\",\"params\":[],\"as\":\"gw_count_fid\"}}],\"rows\":[{\"dragId\":\"gw_m0sL\",\"fid\":\"GW_6W8NGR74JPZL79YD8TW2IX1DC\",\"name\":\"types_of_waste\",\"basename\":\"types_of_waste\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\",\"sort\":\"descending\"}],\"columns\":[{\"dragId\":\"gw_uXJb\",\"fid\":\"GW_943084LMSK2YLWBT63C7VUGNVJYFLPBU4SKTZMLJJSPIO\",\"name\":\"etroi_establishments_number\",\"basename\":\"etroi_establishments_number\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"}],\"color\":[],\"opacity\":[],\"size\":[],\"shape\":[],\"radius\":[],\"theta\":[],\"longitude\":[],\"latitude\":[],\"geoId\":[],\"details\":[],\"filters\":[],\"text\":[]},\"config\":{\"defaultAggregated\":true,\"geoms\":[\"circle\"],\"showTableSummary\":false,\"coordSystem\":\"generic\",\"stack\":\"stack\",\"showActions\":false,\"interactiveScale\":false,\"sorted\":\"none\",\"zeroScale\":true,\"scaleIncludeUnmatchedChoropleth\":false,\"size\":{\"mode\":\"fixed\",\"width\":505,\"height\":520},\"format\":{},\"geoKey\":\"name\",\"resolve\":{\"x\":false,\"y\":false,\"color\":false,\"opacity\":false,\"shape\":false,\"size\":false},\"limit\":-1}},{\"visId\":\"gw_arOM\",\"name\":\"etroi_establishments_number\\t Vs year\",\"encodings\":{\"dimensions\":[{\"dragId\":\"gw_f6av\",\"fid\":\"GW_1BBA6IQGC0\",\"name\":\"year\",\"basename\":\"year\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_S_Br\",\"fid\":\"GW_6W8NGR74JPZL79YD8TW2IX1DC\",\"name\":\"types_of_waste\",\"basename\":\"types_of_waste\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"measures\":[{\"dragId\":\"gw_OdJO\",\"fid\":\"GW_943084LMSK2YLWBT63C7VUGNVJYFLPBU4SKTZMLJJSPIO\",\"name\":\"etroi_establishments_number\",\"basename\":\"etroi_establishments_number\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_R4I3\",\"fid\":\"GW_XH261AU4J9MH4I3XQQL97W5DAYL2R2013ZE1M8TS\",\"name\":\"generated_waste_quantity\",\"basename\":\"generated_waste_quantity\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_count_fid\",\"fid\":\"gw_count_fid\",\"name\":\"Row count\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\",\"computed\":true,\"expression\":{\"op\":\"one\",\"params\":[],\"as\":\"gw_count_fid\"}}],\"rows\":[{\"dragId\":\"gw_fHAO\",\"fid\":\"GW_1BBA6IQGC0\",\"name\":\"year\",\"basename\":\"year\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"columns\":[{\"dragId\":\"gw_-Y7Y\",\"fid\":\"GW_943084LMSK2YLWBT63C7VUGNVJYFLPBU4SKTZMLJJSPIO\",\"name\":\"etroi_establishments_number\",\"basename\":\"etroi_establishments_number\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"}],\"color\":[{\"dragId\":\"gw_5z68\",\"fid\":\"GW_943084LMSK2YLWBT63C7VUGNVJYFLPBU4SKTZMLJJSPIO\",\"name\":\"etroi_establishments_number\",\"basename\":\"etroi_establishments_number\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"}],\"opacity\":[],\"size\":[],\"shape\":[],\"radius\":[],\"theta\":[],\"longitude\":[],\"latitude\":[],\"geoId\":[],\"details\":[],\"filters\":[],\"text\":[]},\"config\":{\"defaultAggregated\":true,\"geoms\":[\"auto\"],\"showTableSummary\":false,\"coordSystem\":\"generic\",\"stack\":\"stack\",\"showActions\":false,\"interactiveScale\":false,\"sorted\":\"none\",\"zeroScale\":true,\"scaleIncludeUnmatchedChoropleth\":false,\"size\":{\"mode\":\"fixed\",\"width\":478,\"height\":280},\"format\":{},\"geoKey\":\"name\",\"resolve\":{\"x\":false,\"y\":false,\"color\":false,\"opacity\":false,\"shape\":false,\"size\":false},\"limit\":-1,\"useSvg\":true}},{\"visId\":\"gw_h1lP\",\"name\":\"Chart 4\",\"encodings\":{\"dimensions\":[{\"dragId\":\"gw_rUXW\",\"fid\":\"GW_1BBA6IQGC0\",\"name\":\"year\",\"basename\":\"year\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"},{\"dragId\":\"gw_qf98\",\"fid\":\"GW_6W8NGR74JPZL79YD8TW2IX1DC\",\"name\":\"types_of_waste\",\"basename\":\"types_of_waste\",\"semanticType\":\"nominal\",\"analyticType\":\"dimension\"}],\"measures\":[{\"dragId\":\"gw_tB_g\",\"fid\":\"GW_943084LMSK2YLWBT63C7VUGNVJYFLPBU4SKTZMLJJSPIO\",\"name\":\"etroi_establishments_number\",\"basename\":\"etroi_establishments_number\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_2AIM\",\"fid\":\"GW_XH261AU4J9MH4I3XQQL97W5DAYL2R2013ZE1M8TS\",\"name\":\"generated_waste_quantity\",\"basename\":\"generated_waste_quantity\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\"},{\"dragId\":\"gw_count_fid\",\"fid\":\"gw_count_fid\",\"name\":\"Row count\",\"analyticType\":\"measure\",\"semanticType\":\"quantitative\",\"aggName\":\"sum\",\"computed\":true,\"expression\":{\"op\":\"one\",\"params\":[],\"as\":\"gw_count_fid\"}}],\"rows\":[],\"columns\":[],\"color\":[],\"opacity\":[],\"size\":[],\"shape\":[],\"radius\":[],\"theta\":[],\"longitude\":[],\"latitude\":[],\"geoId\":[],\"details\":[],\"filters\":[],\"text\":[]},\"config\":{\"defaultAggregated\":false,\"geoms\":[\"auto\"],\"showTableSummary\":false,\"coordSystem\":\"generic\",\"stack\":\"stack\",\"showActions\":false,\"interactiveScale\":false,\"sorted\":\"none\",\"zeroScale\":true,\"scaleIncludeUnmatchedChoropleth\":false,\"size\":{\"mode\":\"fixed\",\"width\":320,\"height\":200},\"format\":{},\"geoKey\":\"name\",\"resolve\":{\"x\":false,\"y\":false,\"color\":false,\"opacity\":false,\"shape\":false,\"size\":false},\"limit\":-1,\"useSvg\":false}}]","chart_map":{},"version":"0.3.7"}"""
pyg.walk(df, spec=vis_spec, dark='dark')
# Out:
# WARNING: parse invoke code failed, This may affect feature of export code.
# Box(children=(HTML(value='<div id="ifr-pyg-6" style="height: auto">\n    <head>\n        <meta http-equiv="Con…
# <html>
# <style>
# .tabs{
#     position:relative;
#     height:660px;
# }
# .tab-pane{
#     display:inline-block;
# }
# .tabs input[type='radio']{
#     position:absolute;
#     clip:rect(0,0,0,0)
# }
# .tab-item{
#     display:block;
#     height:34px;
#     line-height:34px;
#     cursor:pointer;
#     padding:0 10px
# }
#
# .tabs input[type='radio']:checked+.tab-item{
#     background:#2563eb;
#     color:#fff
# }
#
# .tab-content{
#     display: none;
#     position:absolute;
#     left:0;
#     top:56px;
#     bottom:0;
#     right:0;
# }
#
# .tabs input[type='radio']:checked+.tab-item+.tab-content{
#     display: block;
# }
# </style>
#
# <body>
#     <div id="pygwalker-preview-6">
#         <div class="tabs">
#
#             <div class="tab-pane">
#
#                 <input type="radio" name="tab-pyg-6" id="tab-6-yearVsgenerated_waste_quantity" checked />
#
#                 <label class="tab-item" for="tab-6-yearVsgenerated_waste_quantity">year Vs generated_waste_quantity</label>
#                 <div class="tab-content"><div id="6-yearVsgenerated_waste_quantity" style="width: 100%; max-height: 600px;">
#
#     <p style="color: #666; font-weight: 300; padding-inline-start: 1rem;"></p>
#     <!-- <p>Under certain Jupyter environments, after launching pygwalker, the preview may not automatically hide. You can manually click the button to hide it.</p> -->
#     <div class="main-box">
#
#         <div style="display: flex;">
#
#             <div style="width: 423px; height: 208px">
#                 <img style="max-width: none;" height="208" width="413" src="data:image/png;base64,..." />
#             </div>
#
#         </div>
#
#     </div>
# </div></div>
#             </div>
#
#             <div class="tab-pane">
#
#                 <input type="radio" name="tab-pyg-6" id="tab-6-etroi_establishments_numberVstypes_of_waste" />
#
#                 <label class="tab-item" for="tab-6-etroi_establishments_numberVstypes_of_waste">etroi_establishments_number Vs types_of_waste</label>
#                 <div class="tab-content"><div id="6-etroi_establishments_numberVstypes_of_waste" style="width: 100%; max-height: 600px;">
#
#     <p style="color: #666; font-weight: 300; padding-inline-start: 1rem;"></p>
#     <!-- <p>Under certain Jupyter environments, after launching pygwalker, the preview may not automatically hide. You can manually click the button to hide it.</p> -->
#     <div class="main-box">
#
#         <div style="display: flex;">
#
#             <div style="width: 477px; height: 482px">
#                 <img style="max-width: none;" height="482" width="467" src="data:image/png;base64,..." />
#             </div>
#
#         </div>
#
#     </div>
# </div></div>
#             </div>
#
#             <div class="tab-pane">
#
#                 <input type="radio" name="tab-pyg-6" id="tab-6-etroi_establishments_number	Vsyear" />
#
#                 <label class="tab-item" for="tab-6-etroi_establishments_number	Vsyear">etroi_establishments_number	 Vs year</label>
#                 <div class="tab-content"><div id="6-etroi_establishments_number	Vsyear" style="width: 100%; max-height: 600px;">
#
#     <p style="color: #666; font-weight: 300; padding-inline-start: 1rem;"></p>
#     <!-- <p>Under certain Jupyter environments, after launching pygwalker, the preview may not automatically hide. You can manually click the button to hide it.</p> -->
#     <div class="main-box">
#
#         <div style="display: flex;">
#
#             <div style="width: 450px; height: 242px">
#                 <img style="max-width: none;" height="200" width="190" src="data:image/png;base64,..." />
#             </div>
#
#         </div>
#
#     </div>
# </div></div>
#             </div>
#
#             <div class="tab-pane">
#
#                 <input type="radio" name="tab-pyg-6" id="tab-6-Chart4" />
#
#                 <label class="tab-item" for="tab-6-Chart4">Chart 4</label>
#                 <div class="tab-content"><div id="6-Chart4" style="width: 100%; max-height: 600px;">
#
#     <p style="color: #666; font-weight: 300; padding-inline-start: 1rem;"></p>
#     <!-- <p>Under certain Jupyter environments, after launching pygwalker, the preview may not automatically hide. You can manually click the button to hide it.</p> -->
#     <div class="main-box">
#
#         <div style="display: flex;">
#
#             <div style="width: 450px; height: 242px">
#                 <img style="max-width: none;" height="200" width="190" src="data:image/png;base64,..." />
#             </div>
#
#         </div>
#
#     </div>
# </div></div>
#             </div>
#
#         </div>
#     </div>
# </body>
# </html>
