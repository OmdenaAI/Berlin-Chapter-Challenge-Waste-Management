# %% [markdown]
# # EDA on Amount-of Waste-Generated-By-State 32121-0003

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import Data sets
df = pd.read_csv("Amount-of Waste-Generated-By-State 32121-0003.csv", encoding="ISO-8859-1")
df.head()
# Out:
#    ï»¿Year              States                       Types of Waste  \
# 0     2004  Baden-WÃ¼rttemberg  Residual household and bulky wastes
# 1     2004  Baden-WÃ¼rttemberg  Separately collected organic wastes
# 2     2004  Baden-WÃ¼rttemberg     Separately collected recyclables
# 3     2004  Baden-WÃ¼rttemberg                         Other wastes
# 4     2004              Bayern  Residual household and bulky wastes
#
#    Amount of Household Wastes Generated (1000 t)  \
# 0                                         1605.6
# 1                                         1220.5
# 2                                         1645.3
# 3                                            9.4
# 4                                         2039.5
#
#    Amount of Household Wastes Generated p. Inhabitant (kg)
# 0                                                150
# 1                                                114
# 2                                                154
# ...

# %% [markdown]
# ## Preprocessing

# %%
# Display basic information about the dataset
print("Dataset Information:")
print(df.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Data columns (total 5 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   ï»¿Year                                                  1152 non-null   int64
#  1   States                                                   1152 non-null   object
#  2   Types of Waste                                           1152 non-null   object
#  3   Amount of Household Wastes Generated (1000 t)            1152 non-null   float64
#  4   Amount of Household Wastes Generated p. Inhabitant (kg)  1152 non-null   int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 45.1+ KB
# None

# %%
# Summary statistics
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#            ï»¿Year  Amount of Household Wastes Generated (1000 t)  \
# count  1152.000000                                    1152.000000
# mean   2012.500000                                     587.807813
# std       5.190381                                     757.762553
# min    2004.000000                                       0.100000
# 25%    2008.000000                                      57.000000
# 50%    2012.500000                                     291.550000
# 75%    2017.000000                                     775.575000
# max    2021.000000                                    4138.600000
#
#        Amount of Household Wastes Generated p. Inhabitant (kg)
# count                                        1152.000000
# mean                                          112.507812
# std                                            81.070134
# min                                             0.000000
# 25%                                            20.000000
# ...

# %%
# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# ï»¿Year                                                    0
# States                                                     0
# Types of Waste                                             0
# Amount of Household Wastes Generated (1000 t)              0
# Amount of Household Wastes Generated p. Inhabitant (kg)    0
# dtype: int64

# %% [markdown]
# # EDA

# %%
# Visualize the distribution of a numeric column
sns.histplot(df['Amount of Household Wastes Generated (1000 t)'], bins=20)
plt.title('Distribution of Amount of Household Wastes Generated (1000 t)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# Visualize the relationship between two numeric columns
sns.scatterplot(x='Amount of Household Wastes Generated (1000 t)', y='Amount of Household Wastes Generated p. Inhabitant (kg)', data=df)
plt.title('Scatter Plot')
plt.xlabel('Amount of Household Wastes Generated (1000 t)')
plt.ylabel('Amount of Household Wastes Generated p. Inhabitant (kg)')
plt.show()

# %%
# Visualize the relationship between a categorical and a numeric column
sns.boxplot(x='ï»¿Year', y='Amount of Household Wastes Generated (1000 t)', data=df)
plt.title('Box Plot')
plt.xlabel('Year')
plt.ylabel('Numeric ColumnAmount of Household Wastes Generated (1000 t)')
plt.xticks(rotation=45)
plt.show()
