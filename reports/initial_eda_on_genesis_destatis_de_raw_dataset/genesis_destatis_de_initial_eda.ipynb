# %%
import pandas as pd

# %%
genesis_32111_0001 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32111-0001_en.csv')
genesis_32111_0001.head()
# Out:
#    Statistics_Code              Statistics_Label time_code time_label  Time  \
# 0            32111  Collection of waste disposal      JAHR       Jahr  2017
# 1            32111  Collection of waste disposal      JAHR       Jahr  2018
# 2            32111  Collection of waste disposal      JAHR       Jahr  2019
# 3            32111  Collection of waste disposal      JAHR       Jahr  2020
# 4            32111  Collection of waste disposal      JAHR       Jahr  2021
#
#   1_feature_code     1_feature_label 1_expression_code 1_expression_label  \
# 0          DINSG  Germany as a whole                DG        Deutschland
# 1          DINSG  Germany as a whole                DG        Deutschland
# 2          DINSG  Germany as a whole                DG        Deutschland
# 3          DINSG  Germany as a whole                DG        Deutschland
# 4          DINSG  Germany as a whole                DG        Deutschland
#
#    Waste_Disposal_Plants  Input_from_waste_disposal_plants  \
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32111_0001 file belongs to whole Germany, Not Specified to Berlin.`

# %%
genesis_32111_0002 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32111-0002_en.csv')
genesis_32111_0002.head()
# Out:
#    Statistics_Code              Statistics_Label time_code time_label  Time  \
# 0            32111  Collection of waste disposal      JAHR       Jahr  2021
# 1            32111  Collection of waste disposal      JAHR       Jahr  2021
# 2            32111  Collection of waste disposal      JAHR       Jahr  2021
# 3            32111  Collection of waste disposal      JAHR       Jahr  2021
# 4            32111  Collection of waste disposal      JAHR       Jahr  2021
#
#   1_feature_code     1_feature_label 1_expression_code 1_expression_label  \
# 0          DINSG  Germany as a whole                DG        Deutschland
# 1          DINSG  Germany as a whole                DG        Deutschland
# 2          DINSG  Germany as a whole                DG        Deutschland
# 3          DINSG  Germany as a whole                DG        Deutschland
# 4          DINSG  Germany as a whole                DG        Deutschland
#
#   2_feature_code 2_Feature_Label 2_expression_code  \
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32111_0002 file belongs to whole Germany, Not Specified to Berlin.`

# %%
genesis_32111_0003 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32111-0003_en.csv')
genesis_32111_0003.head()
# Out:
#    Statistics_Code              Statistics_Label time_code time_label  Time  \
# 0            32111  Collection of waste disposal      JAHR       Jahr  2021
# 1            32111  Collection of waste disposal      JAHR       Jahr  2021
# 2            32111  Collection of waste disposal      JAHR       Jahr  2021
# 3            32111  Collection of waste disposal      JAHR       Jahr  2021
# 4            32111  Collection of waste disposal      JAHR       Jahr  2021
#
#   1_feature_code     1_feature_label 1_expression_code 1_expression_label  \
# 0          DINSG  Germany as a whole                DG        Deutschland
# 1          DINSG  Germany as a whole                DG        Deutschland
# 2          DINSG  Germany as a whole                DG        Deutschland
# 3          DINSG  Germany as a whole                DG        Deutschland
# 4          DINSG  Germany as a whole                DG        Deutschland
#
#   2_feature_code  ... Input_from_waste_disposal_plants  \
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32111_0003 file belongs to whole Germany, Not Specified to Berlin.`

# %%
genesis_32111_0004 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32111-0004_en.csv')
genesis_32111_0004.head()
# Out:
#    Statistics_Code              Statistics_Label time_code time_label  Time  \
# 0            32111  Collection of waste disposal      JAHR       Jahr  2021
# 1            32111  Collection of waste disposal      JAHR       Jahr  2021
# 2            32111  Collection of waste disposal      JAHR       Jahr  2021
# 3            32111  Collection of waste disposal      JAHR       Jahr  2021
# 4            32111  Collection of waste disposal      JAHR       Jahr  2021
#
#   1_feature_code     1_feature_label 1_expression_code 1_expression_label  \
# 0          DINSG  Germany as a whole                DG        Deutschland
# 1          DINSG  Germany as a whole                DG        Deutschland
# 2          DINSG  Germany as a whole                DG        Deutschland
# 3          DINSG  Germany as a whole                DG        Deutschland
# 4          DINSG  Germany as a whole                DG        Deutschland
#
#   2_feature_code  ... Input_from_waste_disposal_plants  \
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32111_0004 file belongs to whole Germany, Not Specified to Berlin.`

# %%
genesis_32111_0010 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32111-0010_en.csv')
genesis_32111_0010.head()
# Out:
#    Statistics_Code              Statistics_Label time_code time_label  Time  \
# 0            32111  Collection of waste disposal      JAHR       Jahr  2021
# 1            32111  Collection of waste disposal      JAHR       Jahr  2021
# 2            32111  Collection of waste disposal      JAHR       Jahr  2021
# 3            32111  Collection of waste disposal      JAHR       Jahr  2021
# 4            32111  Collection of waste disposal      JAHR       Jahr  2021
#
#   1_feature_code 1_feature_label  1_expression_code  1_expression_label  \
# 0          DLAND  Federal states                  8  Baden-Wuerttemberg
# 1          DLAND  Federal states                  9              Bayern
# 2          DLAND  Federal states                 11              Berlin
# 3          DLAND  Federal states                 12         Brandenburg
# 4          DLAND  Federal states                  4              Bremen
#
#    Waste_Disposal_Plants  Input_from_waste_disposal_plants  \
# ...

# %%
# Filter the DataFrame where the value is "Berlin" with double quotes
berlin_data = genesis_32111_0010[genesis_32111_0010['1_expression_label'] == '"Berlin"']
berlin_data
# Out:
# Empty DataFrame
# Columns: [Statistics_Code, Statistics_Label, time_code, time_label, Time, 1_feature_code, 1_feature_label, 1_expression_code, 1_expression_label, Waste_Disposal_Plants, Input_from_waste_disposal_plants, Waste_generated_in_own_operation, Waste_delivered_from_the_country, Waste_delivered_from_abroad]
# Index: []

# %%
# Check unique values in the '1_expression_label' column to verify the column's actual values
unique_values = genesis_32111_0010['1_expression_label'].unique()
print(unique_values)

# Perform the filtering only if 'Berlin' is present in the column
if '"Berlin"' in unique_values:
    berlin_data = genesis_32111_0010[genesis_32111_0010['1_expression_label'] == '"Berlin"']
    # Now you can work with the 'berlin_data' DataFrame
    print(berlin_data)
else:
    print('Berlin not found in the data.')
# Out:
# shape: (16,)
# Series: '1_expression_label' [str]
# [
# 	"Saarland"
# 	"Bayern"
# 	"Thuringia"
# 	"Saxony-Anhalt"
# 	"Bremen"
# 	"Berlin"
# 	"Brandenburg"
# 	"Lower Saxony"
# 	"Baden-Wuerttem…
# 	"Schleswig-Hols…
# 	"Hamburg"
# 	"Saxony"
# 	"Hesse"
# 	"North Rhine-We…
# 	"Mecklenburg-Vo…
# 	"Rhineland-Pala…
# ]
# Berlin not found in the data.

# %%
# Normalize the column values to handle variations
normalized_values = genesis_32111_0010['1_expression_label'].str.strip('…').str.strip().str.capitalize()

# Filter for "Berlin" regardless of variations in the data
berlin_data_genesis_32111_0010 = genesis_32111_0010[normalized_values == 'Berlin']

# Display the filtered data
berlin_data_genesis_32111_0010
# Out:
#    Statistics_Code              Statistics_Label time_code time_label  Time  \
# 2            32111  Collection of waste disposal      JAHR       Jahr  2021
#
#   1_feature_code 1_feature_label  1_expression_code 1_expression_label  \
# 2          DLAND  Federal states                 11             Berlin
#
#    Waste_Disposal_Plants  Input_from_waste_disposal_plants  \
# 2                    121                            7685.3
#
#    Waste_generated_in_own_operation  Waste_delivered_from_the_country  \
# 2                             195.1                            7428.4
#
#    Waste_delivered_from_abroad
# 2                         61.8

# %% [markdown]
# # *Insights*
#
# `This genesis_32111_0010 file has only one Row specific to Berlin.`

# %%
genesis_32111_0011 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32111-0011_en.csv')
genesis_32111_0011.head()
# Out:
#    Statistics_Code              Statistics_Label time_code time_label  Time  \
# 0            32111  Collection of waste disposal      JAHR       Jahr  2021
# 1            32111  Collection of waste disposal      JAHR       Jahr  2021
# 2            32111  Collection of waste disposal      JAHR       Jahr  2021
# 3            32111  Collection of waste disposal      JAHR       Jahr  2021
# 4            32111  Collection of waste disposal      JAHR       Jahr  2021
#
#   1_feature_code 1_feature_label  1_expression_code  1_expression_label  \
# 0          DLAND  Federal states                  8  Baden-Wuerttemberg
# 1          DLAND  Federal states                  8  Baden-Wuerttemberg
# 2          DLAND  Federal states                  8  Baden-Wuerttemberg
# 3          DLAND  Federal states                  8  Baden-Wuerttemberg
# 4          DLAND  Federal states                  8  Baden-Wuerttemberg
#
#   2_feature_code  ... Input_from_waste_disposal_plants  \
# ...

# %%
# Filter the DataFrame where the value is "Berlin" with double quotes
berlin_data = genesis_32111_0011[genesis_32111_0011['1_expression_label'] == '"Berlin"']
berlin_data
# Out:
# Empty DataFrame
# Columns: [Statistics_Code, Statistics_Label, time_code, time_label, Time, 1_feature_code, 1_feature_label, 1_expression_code, 1_expression_label, 2_feature_code, 2_Feature_Label, 2_expression_code, 2_expression_label, Waste_Disposal_Plants, Input_from_waste_disposal_plants, Waste_generated_in_own_operation, Waste_delivered_from_the_country, Waste_delivered_from_abroad, Waste_disposal_plants_with_output, Output_from_waste_disposal_plants, Waste_for_disposal, Waste_for_recycling, Waste_to_Preparation_Processes, Feed_to_Other]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Normalize the column values to handle variations
normalized_values = genesis_32111_0011['1_expression_label'].str.strip('…').str.strip().str.capitalize()

# Filter for "Berlin" regardless of variations in the data
berlin_data_genesis_32111_0011 = genesis_32111_0011[normalized_values == 'Berlin']

# Display the filtered data
berlin_data_genesis_32111_0011
# Out:
#     Statistics_Code              Statistics_Label time_code time_label  Time  \
# 30            32111  Collection of waste disposal      JAHR       Jahr  2021
# 31            32111  Collection of waste disposal      JAHR       Jahr  2021
# 32            32111  Collection of waste disposal      JAHR       Jahr  2021
# 33            32111  Collection of waste disposal      JAHR       Jahr  2021
# 34            32111  Collection of waste disposal      JAHR       Jahr  2021
# 35            32111  Collection of waste disposal      JAHR       Jahr  2021
# 36            32111  Collection of waste disposal      JAHR       Jahr  2021
# 37            32111  Collection of waste disposal      JAHR       Jahr  2021
# 38            32111  Collection of waste disposal      JAHR       Jahr  2021
# 39            32111  Collection of waste disposal      JAHR       Jahr  2021
# 40            32111  Collection of waste disposal      JAHR       Jahr  2021
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32111_0011 file has only 15 Row specific to Berlin. And most of values are NaN only.`

# %%
genesis_32121_0001 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32121-0001_en.csv')
genesis_32121_0001.head()
# Out:
#    Statistics_Code                     Statistics_Label time_code time_label  \
# 0            32121  Survey of the public Waste disposal      JAHR       Jahr
# 1            32121  Survey of the public Waste disposal      JAHR       Jahr
# 2            32121  Survey of the public Waste disposal      JAHR       Jahr
# 3            32121  Survey of the public Waste disposal      JAHR       Jahr
# 4            32121  Survey of the public Waste disposal      JAHR       Jahr
#
#    Time 1_feature_code     1_feature_label 1_expression_code  \
# 0  2021          DINSG  Germany as a whole                DG
# 1  2021          DINSG  Germany as a whole                DG
# 2  2021          DINSG  Germany as a whole                DG
# 3  2021          DINSG  Germany as a whole                DG
# 4  2021          DINSG  Germany as a whole                DG
#
#   1_expression_label 2_feature_code 2_Feature_Label 2_expression_code  \
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32121_0001 file belongs to whole Germany, Not Specified to Berlin.`

# %%
genesis_32121_0002 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32121-0002_en.csv')
genesis_32121_0002.head()
# Out:
#    Statistics_Code                     Statistics_Label time_code time_label  \
# 0            32121  Survey of the public Waste disposal      JAHR       Jahr
# 1            32121  Survey of the public Waste disposal      JAHR       Jahr
# 2            32121  Survey of the public Waste disposal      JAHR       Jahr
# 3            32121  Survey of the public Waste disposal      JAHR       Jahr
# 4            32121  Survey of the public Waste disposal      JAHR       Jahr
#
#    Time 1_feature_code 1_feature_label  1_expression_code  1_expression_label  \
# 0  2021          DLAND  Federal states                8.0  Baden-Wuerttemberg
# 1  2021          DLAND  Federal states                9.0              Bayern
# 2  2021          DLAND  Federal states               11.0              Berlin
# 3  2021          DLAND  Federal states               12.0         Brandenburg
# 4  2021          DLAND  Federal states                4.0              Bremen
#
# ...

# %%
# Filter the DataFrame where the value is "Berlin" with double quotes
berlin_data = genesis_32121_0002[genesis_32121_0002['1_expression_label'] == '"Berlin"']
berlin_data
# Out:
# Empty DataFrame
# Columns: [Statistics_Code, Statistics_Label, time_code, time_label, Time, 1_feature_code, 1_feature_label, 1_expression_code, 1_expression_label, Amount_of_household_waste, Generation_of_household_waste_per_inhabitant, Household_waste_removed_by_stampers, Household_waste_recycled_at_the_stamp_receiver]
# Index: []

# %%
# Normalize the column values to handle variations
normalized_values = genesis_32121_0002['1_expression_label'].str.strip('…').str.strip().str.capitalize()

# Filter for "Berlin" regardless of variations in the data
berlin_data_genesis_32121_0002 = genesis_32121_0002[normalized_values == 'Berlin']

# Display the filtered data
berlin_data_genesis_32121_0002
# Out:
#    Statistics_Code                     Statistics_Label time_code time_label  \
# 2            32121  Survey of the public Waste disposal      JAHR       Jahr
#
#    Time 1_feature_code 1_feature_label  1_expression_code 1_expression_label  \
# 2  2021          DLAND  Federal states               11.0             Berlin
#
#    Amount_of_household_waste  Generation_of_household_waste_per_inhabitant  \
# 2                     1406.8                                           383
#
#    Household_waste_removed_by_stampers  \
# 2                                  0.3
#
#    Household_waste_recycled_at_the_stamp_receiver
# 2                                          1406.5

# %% [markdown]
# # *Insights*
#
# `This genesis_32121_0002 file has only one Row specific to Berlin.`

# %%
genesis_32121_0003 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32121-0003_en.csv')
genesis_32121_0003.head()
# Out:
#    Statistics_Code                     Statistics_Label time_code time_label  \
# 0            32121  Survey of the public Waste disposal      JAHR       Jahr
# 1            32121  Survey of the public Waste disposal      JAHR       Jahr
# 2            32121  Survey of the public Waste disposal      JAHR       Jahr
# 3            32121  Survey of the public Waste disposal      JAHR       Jahr
# 4            32121  Survey of the public Waste disposal      JAHR       Jahr
#
#    Time 1_feature_code 1_feature_label  1_expression_code  1_expression_label  \
# 0  2021          DLAND  Federal states                8.0  Baden-Wuerttemberg
# 1  2021          DLAND  Federal states                8.0  Baden-Wuerttemberg
# 2  2021          DLAND  Federal states                8.0  Baden-Wuerttemberg
# 3  2021          DLAND  Federal states                8.0  Baden-Wuerttemberg
# 4  2021          DLAND  Federal states                8.0  Baden-Wuerttemberg
#
# ...

# %%
# Filter the DataFrame where the value is "Berlin" with double quotes
berlin_data = genesis_32121_0003[genesis_32121_0003['1_expression_label'] == '"Berlin"']
berlin_data
# Out:
# Empty DataFrame
# Columns: [Statistics_Code, Statistics_Label, time_code, time_label, Time, 1_feature_code, 1_feature_label, 1_expression_code, 1_expression_label, 2_feature_code, 2_Feature_Label, 2_expression_code, 2_expression_label, Amount_of_household_waste, Generation_of_household_waste_per_inhabitant]
# Index: []

# %%
# Normalize the column values to handle variations
normalized_values = genesis_32121_0003['1_expression_label'].str.strip('…').str.strip().str.capitalize()

# Filter for "Berlin" regardless of variations in the data
berlin_data_genesis_32121_0003 = genesis_32121_0003[normalized_values == 'Berlin']

# Display the filtered data
berlin_data_genesis_32121_0003
# Out:
#     Statistics_Code                     Statistics_Label time_code time_label  \
# 10            32121  Survey of the public Waste disposal      JAHR       Jahr
# 11            32121  Survey of the public Waste disposal      JAHR       Jahr
# 12            32121  Survey of the public Waste disposal      JAHR       Jahr
# 13            32121  Survey of the public Waste disposal      JAHR       Jahr
# 14            32121  Survey of the public Waste disposal      JAHR       Jahr
#
#     Time 1_feature_code 1_feature_label  1_expression_code 1_expression_label  \
# 10  2021          DLAND  Federal states               11.0             Berlin
# 11  2021          DLAND  Federal states               11.0             Berlin
# 12  2021          DLAND  Federal states               11.0             Berlin
# 13  2021          DLAND  Federal states               11.0             Berlin
# 14  2021          DLAND  Federal states               11.0             Berlin
#
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32121_0003 file has only 5 Row specific to Berlin.`

# %%
genesis_32131_0001 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32131-0001_en.csv')
genesis_32131_0001.head()
# Out:
#    Statistics_Code                                   Statistics_Label  \
# 0            32131  Eth. i.e. collection from. Transport and outer...
# 1            32131  Eth. i.e. collection from. Transport and outer...
# 2            32131  Eth. i.e. collection from. Transport and outer...
# 3            32131  Eth. i.e. collection from. Transport and outer...
# 4            32131  Eth. i.e. collection from. Transport and outer...
#
#   time_code time_label  Time 1_feature_code     1_feature_label  \
# 0      JAHR       Jahr  2001          DINSG  Germany as a whole
# 1      JAHR       Jahr  2002          DINSG  Germany as a whole
# 2      JAHR       Jahr  2003          DINSG  Germany as a whole
# 3      JAHR       Jahr  2004          DINSG  Germany as a whole
# 4      JAHR       Jahr  2005          DINSG  Germany as a whole
#
#   1_expression_code 1_expression_label  \
# 0                DG        Deutschland
# 1                DG        Deutschland
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32121_0001 file belongs to whole Germany, Not Specified to Berlin.`

# %%
genesis_32131_0002 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32131-0002_en.csv')
genesis_32131_0002.head()
# Out:
#    Statistics_Code                                   Statistics_Label  \
# 0            32131  Eth. i.e. collection from. Transport and outer...
# 1            32131  Eth. i.e. collection from. Transport and outer...
# 2            32131  Eth. i.e. collection from. Transport and outer...
# 3            32131  Eth. i.e. collection from. Transport and outer...
# 4            32131  Eth. i.e. collection from. Transport and outer...
#
#   time_code time_label  Time 1_feature_code     1_feature_label  \
# 0      JAHR       Jahr  2020          DINSG  Germany as a whole
# 1      JAHR       Jahr  2020          DINSG  Germany as a whole
# 2      JAHR       Jahr  2020          DINSG  Germany as a whole
# 3      JAHR       Jahr  2020          DINSG  Germany as a whole
# 4      JAHR       Jahr  2020          DINSG  Germany as a whole
#
#   1_expression_code 1_expression_label 2_feature_code  \
# 0                DG        Deutschland         VPKVB1
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32121_0002 file belongs to whole Germany, Not Specified to Berlin.`

# %%
genesis_32131_0003 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32131-0003_en.csv')
genesis_32131_0003.head()
# Out:
#    Statistics_Code                                   Statistics_Label  \
# 0            32131  Eth. i.e. collection from. Transport and outer...
# 1            32131  Eth. i.e. collection from. Transport and outer...
# 2            32131  Eth. i.e. collection from. Transport and outer...
# 3            32131  Eth. i.e. collection from. Transport and outer...
# 4            32131  Eth. i.e. collection from. Transport and outer...
#
#   time_code time_label  Time 1_feature_code 1_feature_label  \
# 0      JAHR       Jahr  2020          DLAND  Federal states
# 1      JAHR       Jahr  2020          DLAND  Federal states
# 2      JAHR       Jahr  2020          DLAND  Federal states
# 3      JAHR       Jahr  2020          DLAND  Federal states
# 4      JAHR       Jahr  2020          DLAND  Federal states
#
#    1_expression_code  1_expression_label 2_feature_code  \
# 0                  8  Baden-Wuerttemberg         VPKVB1
# 1                  8  Baden-Wuerttemberg         VPKVB1
# ...

# %%
# Filter the DataFrame where the value is "Berlin" with double quotes
berlin_data = genesis_32131_0003[genesis_32131_0003['1_expression_label'] == '"Berlin"']
berlin_data
# Out:
# Empty DataFrame
# Columns: [Statistics_Code, Statistics_Label, time_code, time_label, Time, 1_feature_code, 1_feature_label, 1_expression_code, 1_expression_label, 2_feature_code, 2_Feature_Label, 2_expression_code, 2_expression_label, Collected_transport_and_outer_packaging]
# Index: []

# %%
# Normalize the column values to handle variations
normalized_values = genesis_32131_0003['1_expression_label'].str.strip('…').str.strip().str.capitalize()

# Filter for "Berlin" regardless of variations in the data
berlin_data_genesis_32131_0003 = genesis_32131_0003[normalized_values == 'Berlin']

# Display the filtered data
berlin_data_genesis_32131_0003
# Out:
#    Statistics_Code                                   Statistics_Label  \
# 6            32131  Eth. i.e. collection from. Transport and outer...
# 7            32131  Eth. i.e. collection from. Transport and outer...
# 8            32131  Eth. i.e. collection from. Transport and outer...
#
#   time_code time_label  Time 1_feature_code 1_feature_label  \
# 6      JAHR       Jahr  2020          DLAND  Federal states
# 7      JAHR       Jahr  2020          DLAND  Federal states
# 8      JAHR       Jahr  2020          DLAND  Federal states
#
#    1_expression_code 1_expression_label 2_feature_code  \
# 6                 11             Berlin         VPKVB1
# 7                 11             Berlin         VPKVB1
# 8                 11             Berlin         VPKVB1
#
#                 2_Feature_Label 2_expression_code  \
# 6  whereabouts of the packaging       ANL-SORT-02
# 7  whereabouts of the packaging    BTR-VERWERT-02
# 8  whereabouts of the packaging               NaN
#
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32131_0003 file has only 3 Row specific to Berlin. And most of values are NaN only.`

# %%
genesis_32136_0002 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32136-0002_en.csv')
genesis_32136_0002.head()
# Out:
#    Statistics_Code                    Statistics_Label time_code time_label  \
# 0            32136  Survey of returned sales packaging      JAHR       Jahr
# 1            32136  Survey of returned sales packaging      JAHR       Jahr
# 2            32136  Survey of returned sales packaging      JAHR       Jahr
#
#    Time 1_feature_code     1_feature_label 1_expression_code  \
# 0  2020          DINSG  Germany as a whole                DG
# 1  2020          DINSG  Germany as a whole                DG
# 2  2020          DINSG  Germany as a whole                DG
#
#   1_expression_label 2_feature_code 2_Feature_Label 2_expression_code  \
# 0        Deutschland         VPKRN1    Return Types        VPK-RN-BRA
# 1        Deutschland         VPKRN1    Return Types        VPK-RN-SYS
# 2        Deutschland         VPKRN1    Return Types               NaN
#
#    2_expression_label  Company_Number  \
# 0  Industry Solutions               7
# 1     system operator               9
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32136_0002 file belongs to whole Germany, Not Specified to Berlin.`

# %%
genesis_32136_0003 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32136-0003_en.csv')
genesis_32136_0003.head()
# Out:
#    Statistics_Code                    Statistics_Label time_code time_label  \
# 0            32136  Survey of returned sales packaging      JAHR       Jahr
# 1            32136  Survey of returned sales packaging      JAHR       Jahr
# 2            32136  Survey of returned sales packaging      JAHR       Jahr
# 3            32136  Survey of returned sales packaging      JAHR       Jahr
# 4            32136  Survey of returned sales packaging      JAHR       Jahr
#
#    Time 1_feature_code     1_feature_label 1_expression_code  \
# 0  2020          DINSG  Germany as a whole                DG
# 1  2020          DINSG  Germany as a whole                DG
# 2  2020          DINSG  Germany as a whole                DG
# 3  2020          DINSG  Germany as a whole                DG
# 4  2020          DINSG  Germany as a whole                DG
#
#   1_expression_label 2_feature_code   2_Feature_Label 2_expression_code  \
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32136_0003 file belongs to whole Germany, Not Specified to Berlin.`

# %%
genesis_32136_0004 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32136-0004_en.csv')
genesis_32136_0004.head()
# Out:
#    Statistics_Code                    Statistics_Label time_code time_label  \
# 0            32136  Survey of returned sales packaging      JAHR       Jahr
# 1            32136  Survey of returned sales packaging      JAHR       Jahr
# 2            32136  Survey of returned sales packaging      JAHR       Jahr
# 3            32136  Survey of returned sales packaging      JAHR       Jahr
# 4            32136  Survey of returned sales packaging      JAHR       Jahr
#
#    Time 1_feature_code     1_feature_label 1_expression_code  \
# 0  2020          DINSG  Germany as a whole                DG
# 1  2020          DINSG  Germany as a whole                DG
# 2  2020          DINSG  Germany as a whole                DG
# 3  2020          DINSG  Germany as a whole                DG
# 4  2020          DINSG  Germany as a whole                DG
#
#   1_expression_label 2_feature_code     2_Feature_Label 2_expression_code  \
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32136_0004 file belongs to whole Germany, Not Specified to Berlin.`

# %%
genesis_32136_0005 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32136-0005_en.csv')
genesis_32136_0005.head()
# Out:
#    Statistics_Code                    Statistics_Label time_code time_label  \
# 0            32136  Survey of returned sales packaging      JAHR       Jahr
# 1            32136  Survey of returned sales packaging      JAHR       Jahr
# 2            32136  Survey of returned sales packaging      JAHR       Jahr
# 3            32136  Survey of returned sales packaging      JAHR       Jahr
# 4            32136  Survey of returned sales packaging      JAHR       Jahr
#
#    Time 1_feature_code     1_feature_label 1_expression_code  \
# 0  2020          DINSG  Germany as a whole                DG
# 1  2020          DINSG  Germany as a whole                DG
# 2  2020          DINSG  Germany as a whole                DG
# 3  2020          DINSG  Germany as a whole                DG
# 4  2020          DINSG  Germany as a whole                DG
#
#   1_expression_label 2_feature_code        2_Feature_Label 2_expression_code  \
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32136_0005 file belongs to whole Germany, Not Specified to Berlin.`

# %%
genesis_32136_0006 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32136-0006_en.csv')
genesis_32136_0006.head()
# Out:
#    Statistics_Code                    Statistics_Label time_code time_label  \
# 0            32136  Survey of returned sales packaging      JAHR       Jahr
# 1            32136  Survey of returned sales packaging      JAHR       Jahr
# 2            32136  Survey of returned sales packaging      JAHR       Jahr
# 3            32136  Survey of returned sales packaging      JAHR       Jahr
# 4            32136  Survey of returned sales packaging      JAHR       Jahr
#
#    Time 1_feature_code     1_feature_label 1_expression_code  \
# 0  2020          DINSG  Germany as a whole                DG
# 1  2020          DINSG  Germany as a whole                DG
# 2  2020          DINSG  Germany as a whole                DG
# 3  2020          DINSG  Germany as a whole                DG
# 4  2020          DINSG  Germany as a whole                DG
#
#   1_expression_label 2_feature_code   2_Feature_Label 2_expression_code  \
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32136_0006 file belongs to whole Germany, Not Specified to Berlin.`

# %%
genesis_32136_0010 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32136-0010_en.csv')
genesis_32136_0010.head()
# Out:
#    Statistics_Code                    Statistics_Label time_code time_label  \
# 0            32136  Survey of returned sales packaging      JAHR       Jahr
# 1            32136  Survey of returned sales packaging      JAHR       Jahr
# 2            32136  Survey of returned sales packaging      JAHR       Jahr
# 3            32136  Survey of returned sales packaging      JAHR       Jahr
# 4            32136  Survey of returned sales packaging      JAHR       Jahr
#
#    Time 1_feature_code 1_feature_label  1_expression_code  1_expression_label  \
# 0  2020          DLAND  Federal states                  8  Baden-Wuerttemberg
# 1  2020          DLAND  Federal states                  9              Bayern
# 2  2020          DLAND  Federal states                 11              Berlin
# 3  2020          DLAND  Federal states                 12         Brandenburg
# 4  2020          DLAND  Federal states                  4              Bremen
#
# ...

# %%
# Filter the DataFrame where the value is "Berlin" with double quotes
berlin_data = genesis_32136_0010[genesis_32136_0010['1_expression_label'] == '"Berlin"']
berlin_data
# Out:
# Empty DataFrame
# Columns: [Statistics_Code, Statistics_Label, time_code, time_label, Time, 1_feature_code, 1_feature_label, 1_expression_code, 1_expression_label, Company_Number, Recorded_Sales_Packaging_From_Private_End_Users, Erf._Sales packaging_v._priv._final_burn._per_inv]
# Index: []

# %%
# Normalize the column values to handle variations
normalized_values = genesis_32136_0010['1_expression_label'].str.strip('…').str.strip().str.capitalize()

# Filter for "Berlin" regardless of variations in the data
berlin_data_genesis_32136_0010 = genesis_32136_0010[normalized_values == 'Berlin']

# Display the filtered data
berlin_data_genesis_32136_0010
# Out:
#    Statistics_Code                    Statistics_Label time_code time_label  \
# 2            32136  Survey of returned sales packaging      JAHR       Jahr
#
#    Time 1_feature_code 1_feature_label  1_expression_code 1_expression_label  \
# 2  2020          DLAND  Federal states                 11             Berlin
#
#   Company_Number  Recorded_Sales_Packaging_From_Private_End_Users  \
# 2              .                                            191.7
#
#    Erf._Sales packaging_v._priv._final_burn._per_inv
# 2                                                 52

# %% [markdown]
# # *Insights*
#
# `This genesis_32136_0010 file has only one Row specific to Berlin.`

# %%
genesis_32136_0011 = pd.read_csv('/home/milan/Berlin-Chapter-Challenge-Waste-Management/src/data/clean data/genesis_destatis_de/cleaned-32136-0011_en.csv')
genesis_32136_0011.head()
# Out:
#    Statistics_Code                    Statistics_Label time_code time_label  \
# 0            32136  Survey of returned sales packaging      JAHR       Jahr
# 1            32136  Survey of returned sales packaging      JAHR       Jahr
# 2            32136  Survey of returned sales packaging      JAHR       Jahr
# 3            32136  Survey of returned sales packaging      JAHR       Jahr
# 4            32136  Survey of returned sales packaging      JAHR       Jahr
#
#    Time 1_feature_code 1_feature_label  1_expression_code  1_expression_label  \
# 0  2020          DLAND  Federal states                  8  Baden-Wuerttemberg
# 1  2020          DLAND  Federal states                  8  Baden-Wuerttemberg
# 2  2020          DLAND  Federal states                  8  Baden-Wuerttemberg
# 3  2020          DLAND  Federal states                  8  Baden-Wuerttemberg
# 4  2020          DLAND  Federal states                  8  Baden-Wuerttemberg
#
# ...

# %%
# Filter the DataFrame where the value is "Berlin" with double quotes
berlin_data = genesis_32136_0011[genesis_32136_0011['1_expression_label'] == '"Berlin"']
berlin_data
# Out:
# Empty DataFrame
# Columns: [Statistics_Code, Statistics_Label, time_code, time_label, Time, 1_feature_code, 1_feature_label, 1_expression_code, 1_expression_label, 2_feature_code, 2_Feature_Label, 2_expression_code, 2_expression_label, Recorded_Sales_Packaging_From_Private_End_Users]
# Index: []

# %%
# Normalize the column values to handle variations
normalized_values = genesis_32136_0011['1_expression_label'].str.strip('…').str.strip().str.capitalize()

# Filter for "Berlin" regardless of variations in the data
berlin_data_genesis_32136_0011 = genesis_32136_0011[normalized_values == 'Berlin']

# Display the filtered data
berlin_data_genesis_32136_0011
# Out:
#     Statistics_Code                    Statistics_Label time_code time_label  \
# 16            32136  Survey of returned sales packaging      JAHR       Jahr
# 17            32136  Survey of returned sales packaging      JAHR       Jahr
# 18            32136  Survey of returned sales packaging      JAHR       Jahr
# 19            32136  Survey of returned sales packaging      JAHR       Jahr
# 20            32136  Survey of returned sales packaging      JAHR       Jahr
# 21            32136  Survey of returned sales packaging      JAHR       Jahr
# 22            32136  Survey of returned sales packaging      JAHR       Jahr
# 23            32136  Survey of returned sales packaging      JAHR       Jahr
#
#     Time 1_feature_code 1_feature_label  1_expression_code 1_expression_label  \
# 16  2020          DLAND  Federal states                 11             Berlin
# 17  2020          DLAND  Federal states                 11             Berlin
# ...

# %% [markdown]
# # *Insights*
#
# `This genesis_32136_0010 file has only 8 Row specific to Berlin.`

# %% [markdown]
# ##############################################################################
# ################################# *`Summary`*######################################
# ##############################################################################

# %%
import pandas as pd

# Assuming you already have the seven DataFrames defined, you can create a list of them.
dataframes = [
    berlin_data_genesis_32111_0010,
    berlin_data_genesis_32111_0011,
    berlin_data_genesis_32121_0002,
    berlin_data_genesis_32121_0003,
    berlin_data_genesis_32131_0003,
    berlin_data_genesis_32136_0010,
    berlin_data_genesis_32136_0011
]

# Concatenate the DataFrames vertically
combined_df = pd.concat(dataframes, ignore_index=True)

# Print the combined DataFrame
print("Combined DataFrame:")
print(combined_df)

# Find the total number of records in the combined DataFrame
total_records = combined_df.shape[0]
print(f"Total number of records: {total_records}")
# Out:
# Combined DataFrame:
#     Statistics_Code                                   Statistics_Label  \
# 0             32111                       Collection of waste disposal
# 1             32111                       Collection of waste disposal
# 2             32111                       Collection of waste disposal
# 3             32111                       Collection of waste disposal
# 4             32111                       Collection of waste disposal
# 5             32111                       Collection of waste disposal
# 6             32111                       Collection of waste disposal
# 7             32111                       Collection of waste disposal
# 8             32111                       Collection of waste disposal
# 9             32111                       Collection of waste disposal
# 10            32111                       Collection of waste disposal
# 11            32111                       Collection of waste disposal
# ...

# %%
# Define the Excel file path where you want to save the data
excel_file_path = 'genesis_combined_data.xlsx'

# Export the combined_df DataFrame to an Excel file
combined_df.to_excel(excel_file_path, index=False)

# Provide a confirmation message
print(f"Data has been exported to {excel_file_path}")
# Out:
# Data has been exported to genesis_combined_data.xlsx
